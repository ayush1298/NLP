# %%
import numpy as np
import pandas as pd
from tqdm import tqdm # for peogress checking of the code at the time of training
import multiprocessing as mp # For multiprocessing at the time of training
import warnings # Avoiding unnecessary warnings
from copy import deepcopy # creating a copy
warnings.filterwarnings("ignore")

# %%
train= open("/content/drive/MyDrive/NLP_ass2/NLP2/train.txt",'r')
test=open("/content/drive/MyDrive/NLP_ass2/NLP2/test.txt",'r')

# %% [markdown]
# Change train txt file to a dataframe

# %%
id= None
text = None
rows = []
for line in train:
    if line.strip():
        if line.startswith("# sent_id"):
            id = line.split("=")[-1].strip()
        elif line.startswith("# text"):
            text = line.split("=")[-1].strip()
        else:
            parts = line.split()
            row = {
                'sent_id': id,
                'text': text,
                'word': parts[1],
                'normalized_word': parts[2],
                'POS_tag': parts[3],
                'head_word_index': parts[4],
                'dependency_relation': parts[5]
            }
            rows.append(row)

df_train = pd.DataFrame(rows)

# %%
df_train.head(5)
# Out:
#               sent_id                                     text          word  \
# 0  GUM_academic_art-1  Aesthetic Appreciation and Spanish Art:     Aesthetic
# 1  GUM_academic_art-1  Aesthetic Appreciation and Spanish Art:  Appreciation
# 2  GUM_academic_art-1  Aesthetic Appreciation and Spanish Art:           and
# 3  GUM_academic_art-1  Aesthetic Appreciation and Spanish Art:       Spanish
# 4  GUM_academic_art-1  Aesthetic Appreciation and Spanish Art:           Art
#
#   normalized_word POS_tag head_word_index dependency_relation
# 0       aesthetic      JJ               2                amod
# 1    appreciation      NN               0                root
# 2             and      CC               5                  cc
# 3         Spanish      JJ               5                amod
# 4             art      NN               2                conj

# %% [markdown]
# Change test txt file to a dataframe

# %%
id= None
text = None
rows = []
for line in test:
    if line.strip():
        if line.startswith("# sent_id"):
            id = line.split("=")[-1].strip()
        elif line.startswith("# text"):
            text = line.split("=")[-1].strip()
        else:
            parts = line.split()
            row = {
                'sent_id': id,
                'text': text,
                'word': parts[1],
                'normalized_word': parts[2],
                'POS_tag': parts[3],
                'head_word_index': parts[4],
                'dependency_relation': parts[5]
            }
            rows.append(row)

df_test = pd.DataFrame(rows)

# %%
df_train.shape
# Out:
# (36712, 7)

# %% [markdown]
# # Preprocessing

# %% [markdown]
#  removing all the all rows where head_word_index is equal to '_' which is done so as to remove tokens which are not having any head word relationships

# %%
df_train = df_train[df_train['head_word_index'] != '_']
df_test = df_test[df_test['head_word_index'] != '_']

# %%
df_train.shape
# Out:
# (36249, 7)

# %% [markdown]
# Counting in how many training sentences each token from training set occurs

# %%
df_train['head_word_index'].value_counts()
# Out:
# 0      2000
# 4      1859
# 2      1845
# 3      1845
# 5      1679
#        ...
# 91        3
# 100       3
# 94        3
# 95        2
# 82        1
# Name: head_word_index, Length: 95, dtype: int64

# %% [markdown]
# Creating a Vocabulary as per condition given which is take most frequent 1000 normalized tokens which do not occur in more than 50% of sentences.

# %%
token_sentence_count = df_train.groupby('normalized_word')['sent_id'].nunique()

# Counting total no. of sentences present in training set
total_sentences = len(df_train['sent_id'].unique())

# %% [markdown]
# Filtering the tokens which occur in less than 50% training sentences and then taking top 1000 tokens from those filtered tokens

# %%
filtered_tokens = token_sentence_count[token_sentence_count <= total_sentences * 0.5]
print(len(filtered_tokens))

# Taking top 1000 most frequent tokens from filtered tokens
top_tokens = filtered_tokens.head(1000)
print(len(top_tokens))
# Out:
# 5276
# 1000

# %%
top_tokens_keys=list(top_tokens.keys())

# %%
len(top_tokens_keys)
# Out:
# 1000

# %%
# df_train=df_train[df_train['normalized_word'].isin(top_tokens_keys)]
# train_POS_tags= df_train['POS_tag'].tolist()
# # train_POS_tags
# len(df_train)

# %% [markdown]
# Creating a new column having index of position of each word in the corresponding sentence. This will be used for storing the head word, dependent relationships in arcs

# %%
df_train['normalized_word_index'] = df_train.groupby('sent_id').cumcount()+ 1
df_train.head(25)
# Out:
#                sent_id                                               text  \
# 0   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 1   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 2   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 3   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 4   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 5   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 6   GUM_academic_art-2                         Insights from Eye-Tracking
# 7   GUM_academic_art-2                         Insights from Eye-Tracking
# 8   GUM_academic_art-2                         Insights from Eye-Tracking
# 9   GUM_academic_art-2                         Insights from Eye-Tracking
# 10  GUM_academic_art-2                         Insights from Eye-Tracking
# 11  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 12  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 13  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 14  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 15  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 16  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 17  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 18  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 19  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 20  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 21  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 22  GUM_academic_art-4  Andrew Beresford a.m.beresford@durham.ac.uk Du...
# 23  GUM_academic_art-4  Andrew Beresford a.m.beresford@durham.ac.uk Du...
# 24  GUM_academic_art-4  Andrew Beresford a.m.beresford@durham.ac.uk Du...
#
#                              word                normalized_word POS_tag  \
# 0                       Aesthetic                      aesthetic      JJ
# 1                    Appreciation                   appreciation      NN
# 2                             and                            and      CC
# 3                         Spanish                        Spanish      JJ
# 4                             Art                            art      NN
# 5                               :                              :       :
# 6                        Insights                        insight     NNS
# 7                            from                           from      IN
# 8                             Eye                            eye      NN
# 9                               -                              -    HYPH
# 10                       Tracking                       tracking      NN
# 11                         Claire                         Claire     NNP
# 12                         Bailey                         Bailey     NNP
# 13                              -                              -    HYPH
# 14                           Ross                           Ross     NNP
# 15  claire.bailey-ross@port.ac.uk  claire.bailey-ross@port.ac.uk     NNP
# 16                     University                     University     NNP
# 17                             of                             of      IN
# 18                     Portsmouth                     Portsmouth     NNP
# 19                              ,                              ,       ,
# 20                         United                          Unite     NNP
# 21                        Kingdom                        Kingdom     NNP
# 22                         Andrew                         Andrew     NNP
# 23                      Beresford                      Beresford     NNP
# 24     a.m.beresford@durham.ac.uk     a.m.beresford@durham.ac.uk     NNP
#
#    head_word_index dependency_relation  normalized_word_index
# 0                2                amod                      1
# 1                0                root                      2
# 2                5                  cc                      3
# 3                5                amod                      4
# 4                2                conj                      5
# 5                2               punct                      6
# 6                0                root                      1
# 7                5                case                      2
# 8                5            compound                      3
# 9                3               punct                      4
# 10               1                nmod                      5
# 11               0                root                      1
# 12               1                flat                      2
# 13               4               punct                      3
# 14               2                flat                      4
# 15               1                list                      5
# 16               1                list                      6
# 17               8                case                      7
# 18               6                nmod                      8
# 19              11               punct                      9
# 20              11                amod                     10
# 21               1                list                     11
# 22               0                root                      1
# 23               1                flat                      2
# 24               1                list                      3

# %%
df1 = df_train
for index, row in df1.iterrows():
    df_2 = df1[(df1['sent_id'] == row['sent_id'])]
    df_2 = df_2[int(row['head_word_index']) ==  df_2['normalized_word_index']]
    if int(row['head_word_index'])== 0:
      df1.at[index, 'head_word'] = 'root'
    elif not df_2.empty:
        head_word = df_2['normalized_word'].iloc[0]
        df1.at[index, 'head_word'] = head_word
df_train=df1
df_train.head(25)
# Out:
#                sent_id                                               text  \
# 0   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 1   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 2   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 3   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 4   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 5   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 6   GUM_academic_art-2                         Insights from Eye-Tracking
# 7   GUM_academic_art-2                         Insights from Eye-Tracking
# 8   GUM_academic_art-2                         Insights from Eye-Tracking
# 9   GUM_academic_art-2                         Insights from Eye-Tracking
# 10  GUM_academic_art-2                         Insights from Eye-Tracking
# 11  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 12  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 13  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 14  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 15  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 16  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 17  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 18  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 19  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 20  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 21  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 22  GUM_academic_art-4  Andrew Beresford a.m.beresford@durham.ac.uk Du...
# 23  GUM_academic_art-4  Andrew Beresford a.m.beresford@durham.ac.uk Du...
# 24  GUM_academic_art-4  Andrew Beresford a.m.beresford@durham.ac.uk Du...
#
#                              word                normalized_word POS_tag  \
# 0                       Aesthetic                      aesthetic      JJ
# 1                    Appreciation                   appreciation      NN
# 2                             and                            and      CC
# 3                         Spanish                        Spanish      JJ
# 4                             Art                            art      NN
# 5                               :                              :       :
# 6                        Insights                        insight     NNS
# 7                            from                           from      IN
# 8                             Eye                            eye      NN
# 9                               -                              -    HYPH
# 10                       Tracking                       tracking      NN
# 11                         Claire                         Claire     NNP
# 12                         Bailey                         Bailey     NNP
# 13                              -                              -    HYPH
# 14                           Ross                           Ross     NNP
# 15  claire.bailey-ross@port.ac.uk  claire.bailey-ross@port.ac.uk     NNP
# 16                     University                     University     NNP
# 17                             of                             of      IN
# 18                     Portsmouth                     Portsmouth     NNP
# 19                              ,                              ,       ,
# 20                         United                          Unite     NNP
# 21                        Kingdom                        Kingdom     NNP
# 22                         Andrew                         Andrew     NNP
# 23                      Beresford                      Beresford     NNP
# 24     a.m.beresford@durham.ac.uk     a.m.beresford@durham.ac.uk     NNP
#
#    head_word_index dependency_relation  normalized_word_index     head_word
# 0                2                amod                      1  appreciation
# 1                0                root                      2          root
# 2                5                  cc                      3           art
# 3                5                amod                      4           art
# 4                2                conj                      5  appreciation
# 5                2               punct                      6  appreciation
# 6                0                root                      1          root
# 7                5                case                      2      tracking
# 8                5            compound                      3      tracking
# 9                3               punct                      4           eye
# 10               1                nmod                      5       insight
# 11               0                root                      1          root
# 12               1                flat                      2        Claire
# 13               4               punct                      3          Ross
# 14               2                flat                      4        Bailey
# 15               1                list                      5        Claire
# 16               1                list                      6        Claire
# 17               8                case                      7    Portsmouth
# 18               6                nmod                      8    University
# 19              11               punct                      9       Kingdom
# 20              11                amod                     10       Kingdom
# 21               1                list                     11        Claire
# 22               0                root                      1          root
# 23               1                flat                      2        Andrew
# 24               1                list                      3        Andrew

# %% [markdown]
# True dependency graph which is stored in the form of tuples (head_word, dependent_word)

# %%
df_train['dep_graph']= list(zip(df_train['head_word'], df_train['normalized_word']))
df_train.head(25)
# Out:
#                sent_id                                               text  \
# 0   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 1   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 2   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 3   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 4   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 5   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 6   GUM_academic_art-2                         Insights from Eye-Tracking
# 7   GUM_academic_art-2                         Insights from Eye-Tracking
# 8   GUM_academic_art-2                         Insights from Eye-Tracking
# 9   GUM_academic_art-2                         Insights from Eye-Tracking
# 10  GUM_academic_art-2                         Insights from Eye-Tracking
# 11  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 12  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 13  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 14  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 15  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 16  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 17  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 18  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 19  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 20  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 21  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 22  GUM_academic_art-4  Andrew Beresford a.m.beresford@durham.ac.uk Du...
# 23  GUM_academic_art-4  Andrew Beresford a.m.beresford@durham.ac.uk Du...
# 24  GUM_academic_art-4  Andrew Beresford a.m.beresford@durham.ac.uk Du...
#
#                              word                normalized_word POS_tag  \
# 0                       Aesthetic                      aesthetic      JJ
# 1                    Appreciation                   appreciation      NN
# 2                             and                            and      CC
# 3                         Spanish                        Spanish      JJ
# 4                             Art                            art      NN
# 5                               :                              :       :
# 6                        Insights                        insight     NNS
# 7                            from                           from      IN
# 8                             Eye                            eye      NN
# 9                               -                              -    HYPH
# 10                       Tracking                       tracking      NN
# 11                         Claire                         Claire     NNP
# 12                         Bailey                         Bailey     NNP
# 13                              -                              -    HYPH
# 14                           Ross                           Ross     NNP
# 15  claire.bailey-ross@port.ac.uk  claire.bailey-ross@port.ac.uk     NNP
# 16                     University                     University     NNP
# 17                             of                             of      IN
# 18                     Portsmouth                     Portsmouth     NNP
# 19                              ,                              ,       ,
# 20                         United                          Unite     NNP
# 21                        Kingdom                        Kingdom     NNP
# 22                         Andrew                         Andrew     NNP
# 23                      Beresford                      Beresford     NNP
# 24     a.m.beresford@durham.ac.uk     a.m.beresford@durham.ac.uk     NNP
#
#    head_word_index dependency_relation  normalized_word_index     head_word  \
# 0                2                amod                      1  appreciation
# 1                0                root                      2          root
# 2                5                  cc                      3           art
# 3                5                amod                      4           art
# 4                2                conj                      5  appreciation
# 5                2               punct                      6  appreciation
# 6                0                root                      1          root
# 7                5                case                      2      tracking
# 8                5            compound                      3      tracking
# 9                3               punct                      4           eye
# 10               1                nmod                      5       insight
# 11               0                root                      1          root
# 12               1                flat                      2        Claire
# 13               4               punct                      3          Ross
# 14               2                flat                      4        Bailey
# 15               1                list                      5        Claire
# 16               1                list                      6        Claire
# 17               8                case                      7    Portsmouth
# 18               6                nmod                      8    University
# 19              11               punct                      9       Kingdom
# 20              11                amod                     10       Kingdom
# 21               1                list                     11        Claire
# 22               0                root                      1          root
# 23               1                flat                      2        Andrew
# 24               1                list                      3        Andrew
#
#                                   dep_graph
# 0                 (appreciation, aesthetic)
# 1                      (root, appreciation)
# 2                                (art, and)
# 3                            (art, Spanish)
# 4                       (appreciation, art)
# 5                         (appreciation, :)
# 6                           (root, insight)
# 7                          (tracking, from)
# 8                           (tracking, eye)
# 9                                  (eye, -)
# 10                      (insight, tracking)
# 11                           (root, Claire)
# 12                         (Claire, Bailey)
# 13                                (Ross, -)
# 14                           (Bailey, Ross)
# 15  (Claire, claire.bailey-ross@port.ac.uk)
# 16                     (Claire, University)
# 17                         (Portsmouth, of)
# 18                 (University, Portsmouth)
# 19                             (Kingdom, ,)
# 20                         (Kingdom, Unite)
# 21                        (Claire, Kingdom)
# 22                           (root, Andrew)
# 23                      (Andrew, Beresford)
# 24     (Andrew, a.m.beresford@durham.ac.uk)

# %%
normalised_train_token= df_train['normalized_word'].unique()
token_mapping = {token:i for i, token in enumerate(normalised_train_token)}
token_mapping
# Out:
# {'aesthetic': 0,
#  'appreciation': 1,
#  'and': 2,
#  'Spanish': 3,
#  'art': 4,
#  ':': 5,
#  'insight': 6,
#  'from': 7,
#  'eye': 8,
#  '-': 9,
#  'tracking': 10,
#  'Claire': 11,
#  'Bailey': 12,
#  'Ross': 13,
#  'claire.bailey-ross@port.ac.uk': 14,
#  'University': 15,
#  'of': 16,
#  'Portsmouth': 17,
#  ',': 18,
#  'Unite': 19,
#  'Kingdom': 20,
#  'Andrew': 21,
#  'Beresford': 22,
#  'a.m.beresford@durham.ac.uk': 23,
#  'Durham': 24,
#  'Daniel': 25,
#  'Smith': 26,
#  'daniel.smith2@durham.ac.uk': 27,
#  'Warwick': 28,
#  'c.l.h.warwick@durham.ac.uk': 29,
#  'how': 30,
#  'do': 31,
#  'person': 32,
#  'look': 33,
#  'at': 34,
#  'experience': 35,
#  '?': 36,
#  'which': 37,
#  'element': 38,
#  'specific': 39,
#  'artwork': 40,
#  'they': 41,
#  'focus': 42,
#  'on': 43,
#  'museum': 44,
#  'label': 45,
#  'have': 46,
#  'a': 47,
#  'impact': 48,
#  'the': 49,
#  'viewing': 50,
#  'be': 51,
#  'complex': 52,
#  'one': 53,
#  'involve': 54,
#  'issue': 55,
#  'perception': 56,
#  'attention': 57,
#  'memory': 58,
#  'decision': 59,
#  'make': 60,
#  'affect': 61,
#  'emotion': 62,
#  '.': 63,
#  'thus': 64,
#  'time': 65,
#  'it': 66,
#  'take': 67,
#  'way': 68,
#  'visually': 69,
#  'explore': 70,
#  'can': 71,
#  'inform': 72,
#  'about': 73,
#  'its': 74,
#  'relevance': 75,
#  'interestingness': 76,
#  'even': 77,
#  'appeal': 78,
#  'this': 79,
#  'paper': 80,
#  'describe': 81,
#  'collaborative': 82,
#  'pilot': 83,
#  'project': 84,
#  'unique': 85,
#  'collection': 86,
#  '17th': 87,
#  'century': 88,
#  'Zurbarán': 89,
#  'painting': 90,
#  'Jacob': 91,
#  'Cycle': 92,
#  'Auckland': 93,
#  'Castle': 94,
#  'only': 95,
#  'UK': 96,
#  'example': 97,
#  'continental': 98,
#  'preserve': 99,
#  'in': 100,
#  'situ': 101,
#  'purpose': 102,
#  'build': 103,
#  'surroundings': 104,
#  'while': 105,
#  'study': 106,
#  'psychology': 107,
#  'individual': 108,
#  'work': 109,
#  'distinction': 110,
#  'between': 111,
#  'representative': 112,
#  '/': 113,
#  'non-representative': 114,
#  'topic': 115,
#  'no': 116,
#  'complete': 117,
#  'or': 118,
#  'devotional': 119,
#  'theme': 120,
#  'we': 121,
#  'report': 122,
#  'upon': 123,
#  'novel': 124,
#  'technique': 125,
#  'provide': 126,
#  'into': 127,
#  'unconscious': 128,
#  'process': 129,
#  'view': 130,
#  'to': 131,
#  'assess': 132,
#  'effect': 133,
#  'different': 134,
#  'write': 135,
#  'interpretation': 136,
#  'visual': 137,
#  'exploration': 138,
#  'will': 139,
#  'discuss': 140,
#  'potential': 141,
#  'implication': 142,
#  'our': 143,
#  'understanding': 144,
#  'behaviour': 145,
#  'gallery': 146,
#  'practice': 147,
#  'bring': 148,
#  'together': 149,
#  'establish': 150,
#  'research': 151,
#  'strength': 152,
#  'history': 153,
#  'experimental': 154,
#  'digital': 155,
#  'humanity': 156,
#  'use': 157,
#  'reaction': 158,
#  'representation': 159,
#  'as': 160,
#  'well': 161,
#  'significance': 162,
#  'whole': 163,
#  'develop': 164,
#  'interaction': 165,
#  'several': 166,
#  'cognitive': 167,
#  'affective': 168,
#  ';': 169,
#  'beginning': 170,
#  'scan': 171,
#  'when': 172,
#  'regard': 173,
#  'viewer': 174,
#  'gather': 175,
#  'information': 176,
#  'through': 177,
#  'series': 178,
#  'fixation': 179,
#  'intersperse': 180,
#  'by': 181,
#  'rapid': 182,
#  'movement': 183,
#  'call': 184,
#  'saccade': 185,
#  'direction': 186,
#  'determine': 187,
#  'goal': 188,
#  'observer': 189,
#  'physical': 190,
#  'property': 191,
#  'scene': 192,
#  '(': 193,
#  'e.g.': 194,
#  'colour': 195,
#  'texture': 196,
#  'brightness': 197,
#  'etc.': 198,
#  ')': 199,
#  'importantly': 200,
#  'offer': 201,
#  'that': 202,
#  'not': 203,
#  'depend': 204,
#  'participant': 205,
#  "'s": 206,
#  'belief': 207,
#  'subjective': 208,
#  'impression': 209,
#  'previous': 210,
#  'highlight': 211,
#  'transform': 212,
#  'understand': 213,
#  'processing': 214,
#  'see': 215,
#  'for': 216,
#  'Brieber': 217,
#  '2014': 218,
#  'Binderman': 219,
#  'et': 220,
#  'al.': 221,
#  '2005': 222,
#  'same': 223,
#  'direct': 224,
#  'important': 225,
#  'factor': 226,
#  'visit': 227,
#  'Filippini': 228,
#  'Fantoni': 229,
#  '2013': 230,
#  'Heidenreich': 231,
#  '&': 232,
#  'Turano': 233,
#  '2011': 234,
#  'Milekic': 235,
#  '2010': 236,
#  'cycle': 237,
#  'his': 238,
#  'son': 239,
#  'display': 240,
#  'Long': 241,
#  'Room': 242,
#  'over': 243,
#  '250': 244,
#  'year': 245,
#  'very': 246,
#  'few': 247,
#  'kind': 248,
#  'world': 249,
#  'long': 250,
#  'scholarship': 251,
#  'Baron': 252,
#  'but': 253,
#  'many': 254,
#  'key': 255,
#  'aspect': 256,
#  'production': 257,
#  'yet': 258,
#  'fully': 259,
#  'first': 260,
#  'stage': 261,
#  'audience': 262,
#  'extensive': 263,
#  'County': 264,
#  '13': 265,
#  'there': 266,
#  'actually': 267,
#  '12': 268,
#  '13th': 269,
#  'Benjamin': 270,
#  'copy': 271,
#  'Arthur': 272,
#  'Pond': 273,
#  'part': 274,
#  'investigate': 275,
#  'evaluate': 276,
#  'whether': 277,
#  'encourage': 278,
#  'approach': 279,
#  'primarily': 280,
#  'new': 281,
#  'culture': 282,
#  'namely': 283,
#  'characteristic': 284,
#  'visitor': 285,
#  '1': 286,
#  'introduction': 287,
#  'Tenured': 288,
#  'tenure': 289,
#  'track': 290,
#  'university': 291,
#  'faculty': 292,
#  'play': 293,
#  'special': 294,
#  'role': 295,
#  'speed': 296,
#  'scientific': 297,
#  'progress': 298,
#  'both': 299,
#  'directly': 300,
#  'their': 301,
#  'indirectly': 302,
#  'training': 303,
#  'researcher': 304,
#  'past': 305,
#  'each': 306,
#  'effort': 307,
#  'strongly': 308,
#  'positively': 309,
#  'influence': 310,
#  'various': 311,
#  'form': 312,
#  'diversity': 313,
#  'include': 314,
#  'ethnic': 315,
#  'racial': 316,
#  'gender': 317,
#  'show': 318,
#  'great': 319,
#  'within': 320,
#  'community': 321,
#  'group': 322,
#  'lead': 323,
#  'improve': 324,
#  'critical': 325,
#  'thinking': 326,
#  '[': 327,
#  ']': 328,
#  'more': 329,
#  'creative': 330,
#  'solution': 331,
#  'task': 332,
#  '2': 333,
#  '3': 334,
#  'pair': 335,
#  'with': 336,
#  'skillset': 337,
#  'perspective': 338,
#  'complement': 339,
#  'often': 340,
#  'augment': 341,
#  'ability': 342,
#  'peer': 343,
#  'additionally': 344,
#  'produce': 345,
#  'supportive': 346,
#  'social': 347,
#  'climate': 348,
#  'effective': 349,
#  'learning': 350,
#  'environment': 351,
#  '4': 352,
#  'facilitate': 353,
#  'mentoring': 354,
#  'young': 355,
#  'scientist': 356,
#  'despite': 357,
#  'positive': 358,
#  'however': 359,
#  'quantify': 360,
#  'science': 361,
#  'remain': 362,
#  'exceedingly': 363,
#  'difficult': 364,
#  'due': 365,
#  'large': 366,
#  'lack': 367,
#  'comprehensive': 368,
#  'datum': 369,
#  'workforce': 370,
#  'measure': 371,
#  'composition': 372,
#  'dynamic': 373,
#  'particularly': 374,
#  'rapidly': 375,
#  'expand': 376,
#  'field': 377,
#  'like': 378,
#  'computer': 379,
#  'crucial': 380,
#  'step': 381,
#  'toward': 382,
#  'scholarly': 383,
#  'conduct': 384,
#  'might': 385,
#  'enhance': 386,
#  'central': 387,
#  'listing': 388,
#  'all': 389,
#  'define': 390,
#  'rigorous': 391,
#  'sample': 392,
#  'frame': 393,
#  'analysis': 394,
#  'far': 395,
#  'rate': 396,
#  'adoption': 397,
#  'service': 398,
#  'GoogleScholar': 399,
#  'ResearchGate': 400,
#  'vary': 401,
#  'across': 402,
#  'discipline': 403,
#  'instance': 404,
#  'computing': 405,
#  'broad': 406,
#  '5': 407,
#  'without': 408,
#  'full': 409,
#  'census': 410,
#  'degree': 411,
#  'inequality': 412,
#  'possible': 413,
#  'source': 414,
#  '6': 415,
#  'some': 416,
#  'political': 417,
#  'organize': 418,
#  'around': 419,
#  'single': 420,
#  'professional': 421,
#  'society': 422,
#  'whose': 423,
#  'membership': 424,
#  'roll': 425,
#  'approximate': 426,
#  '7': 427,
#  'most': 428,
#  'other': 429,
#  'hand': 430,
#  'encompass': 431,
#  'organization': 432,
#  'instead': 433,
#  'distribute': 434,
#  'disjoint': 435,
#  'list': 436,
#  'such': 437,
#  'web': 438,
#  'base': 439,
#  'directory': 440,
#  'department': 441,
#  'because': 442,
#  'assemble': 443,
#  'tend': 444,
#  'avoid': 445,
#  '8': 446,
#  '11': 447,
#  'usually': 448,
#  'particular': 449,
#  '16': 450,
#  'elite': 451,
#  '17': 452,
#  '18': 453,
#  'although': 454,
#  'useful': 455,
#  'limited': 456,
#  'generalizability': 457,
#  'date': 458,
#  'nearly': 459,
#  'record': 460,
#  'three': 461,
#  'academic': 462,
#  'business': 463,
#  '19': 464,
#  'set': 465,
#  'shed': 466,
#  'considerable': 467,
#  'light': 468,
#  'dramatic': 469,
#  'placement': 470,
#  'productivity': 471,
#  '20': 472,
#  'snapshot': 473,
#  'evolve': 474,
#  'system': 475,
#  'hence': 476,
#  'change': 477,
#  'trend': 478,
#  'yearly': 479,
#  'number': 480,
#  'available': 481,
#  'aggregate': 482,
#  'Computing': 483,
#  'Research': 484,
#  'Association': 485,
#  'CRA': 486,
#  'document': 487,
#  'employment': 488,
#  'PhD': 489,
#  'recipient': 490,
#  'annual': 491,
#  'Taulbee': 492,
#  'survey': 493,
#  'North': 494,
#  'America': 495,
#  'cra.org/resources/taulbee-survey': 496,
#  'valuable': 497,
#  'summary': 498,
#  'statistic': 499,
#  'suffer': 500,
#  'two': 501,
#  'weakness': 502,
#  'subject': 503,
#  'variable': 504,
#  'response': 505,
#  'misinterpretation': 506,
#  'question': 507,
#  'inject': 508,
#  'bias': 509,
#  'fine': 510,
#  'grain': 511,
#  '21': 512,
#  '22': 513,
#  'second': 514,
#  'high': 515,
#  'level': 516,
#  'causality': 517,
#  '23': 518,
#  'difference': 519,
#  'recruitment': 520,
#  'retention': 521,
#  'strategy': 522,
#  'wash': 523,
#  'out': 524,
#  'averaging': 525,
#  'thereby': 526,
#  'mask': 527,
#  'any': 528,
#  'efficacy': 529,
#  'policy': 530,
#  'here': 531,
#  'present': 532,
#  'topical': 533,
#  'crawler': 534,
#  'quickly': 535,
#  'automatically': 536,
#  'public': 537,
#  'World': 538,
#  'Wide': 539,
#  'Web': 540,
#  'efficient': 541,
#  'accurate': 542,
#  'adapt': 543,
#  'continuous': 544,
#  'capable': 545,
#  'collect': 546,
#  'entire': 547,
#  'just': 548,
#  'hour': 549,
#  'off': 550,
#  'shelf': 551,
#  'hardware': 552,
#  'vast': 553,
#  'improvement': 554,
#  'roughly': 555,
#  '1600': 556,
#  'require': 557,
#  'online': 558,
#  'alone': 559,
#  'access': 560,
#  'rely': 561,
#  'also': 562,
#  'longitudinally': 563,
#  'effectiveness': 564,
#  'mean': 565,
#  'broaden': 566,
#  'participation': 567,
#  'finally': 568,
#  'apply': 569,
#  'parallel': 570,
#  'elucidate': 571,
#  'relate': 572,
#  'labor': 573,
#  'flow': 574,
#  'advance': 575,
#  'short': 576,
#  'benefit': 577,
#  'availability': 578,
#  'frequently': 579,
#  'recollect': 580,
#  'follow': 581,
#  'begin': 582,
#  'detail': 583,
#  'design': 584,
#  'implementation': 585,
#  'framework': 586,
#  'next': 587,
#  'result': 588,
#  'section': 589,
#  'demonstrate': 590,
#  'validity': 591,
#  'utility': 592,
#  'compare': 593,
#  'curate': 594,
#  'type': 595,
#  'enable': 596,
#  '2017': 597,
#  "''": 598,
#  'leaky': 599,
#  'pipeline': 600,
#  'problem': 601,
#  '2.': 602,
#  'institutional': 603,
#  'economics': 604,
#  'theoretical': 605,
#  'foundation': 606,
#  'application': 607,
#  'Argentine': 608,
#  'Case': 609,
#  '2.1.': 610,
#  'right': 611,
#  'credibility': 612,
#  'state': 613,
#  'commitment': 614,
#  'throughout': 615,
#  'half': 616,
#  '20th': 617,
#  'witness': 618,
#  'return': 619,
#  'institution': 620,
#  'economic': 621,
#  'awarding': 622,
#  'Nobel': 623,
#  'Prize': 624,
#  'Economics': 625,
#  'main': 626,
#  'Douglass': 627,
#  'Ronald': 628,
#  'Coase': 629,
#  'Oliver': 630,
#  'Williamson': 631,
#  'Elinor': 632,
#  'Ostrom': 633,
#  'contribute': 634,
#  'recognition': 635,
#  'notion': 636,
#  'concept': 637,
#  'transaction': 638,
#  'cost': 639,
#  'analyze': 640,
#  'respectively': 641,
#  '14': 642,
#  'argue': 643,
#  'where': 644,
#  'outweigh': 645,
#  'gain': 646,
#  'exchange': 647,
#  'place': 648,
#  'rule': 649,
#  'game': 650,
#  'structure': 651,
#  'economy': 652,
#  'incentive': 653,
#  'behavior': 654,
#  'uncertainty': 655,
#  'stimulate': 656,
#  'discourage': 657,
#  'viable': 658,
#  'reduce': 659,
#  'exist': 660,
#  'guarantee': 661,
#  'word': 662,
#  'agent': 663,
#  'believe': 664,
#  'away': 665,
#  'private': 666,
#  'actor': 667,
#  '15': 668,
#  'achieve': 669,
#  'objective': 670,
#  'creation': 671,
#  'inclusive': 672,
#  'incorporate': 673,
#  'impartial': 674,
#  'legal': 675,
#  'promote': 676,
#  'equality': 677,
#  'condition': 678,
#  'course': 679,
#  'must': 680,
#  'protect': 681,
#  'ensure': 682,
#  'sound': 683,
#  'judiciary': 684,
#  'responsible': 685,
#  'impose': 686,
#  'order': 687,
#  'cooperation': 688,
#  'among': 689,
#  'penalize': 690,
#  'violator': 691,
#  'contract': 692,
#  'path': 693,
#  'prosperous': 694,
#  'easy': 695,
#  'adopt': 696,
#  'if': 697,
#  'disagreement': 698,
#  'implement': 699,
#  'then': 700,
#  'win': 701,
#  'final': 702,
#  'pluralist': 703,
#  'centralized': 704,
#  'Inclusive': 705,
#  'equal': 706,
#  'consequence': 707,
#  'reflect': 708,
#  'increase': 709,
#  'activity': 710,
#  'growth': 711,
#  'extractive': 712,
#  'power': 713,
#  'consolidate': 714,
#  'small': 715,
#  'government': 716,
#  'extract': 717,
#  'resource': 718,
#  'rest': 719,
#  'population': 720,
#  'own': 721,
#  'enrichment': 722,
#  'being': 723,
#  'another': 724,
#  'feature': 725,
#  'powerful': 726,
#  'interest': 727,
#  'oppose': 728,
#  'pluralism': 729,
#  'typically': 730,
#  'loss': 731,
#  'privilege': 732,
#  'little': 733,
#  'devolve': 734,
#  'would': 735,
#  'occur': 736,
#  'under': 737,
#  'pluralistic': 738,
#  'essential': 739,
#  'constitution': 740,
#  'restrict': 741,
#  'predatory': 742,
#  'action': 743,
#  '—': 744,
#  'itself': 745,
#  'create': 746,
#  'moreover': 747,
#  'compliance': 748,
#  'mechanism': 749,
#  'ex': 750,
#  'ante': 751,
#  'post': 752,
#  'standard': 753,
#  'what': 754,
#  'happen': 755,
#  'respect': 756,
#  'exhibit': 757,
#  'case': 758,
#  'expropriation': 759,
#  'YPF': 760,
#  'State': 761,
#  'general': 762,
#  'execution': 763,
#  'unfavorable': 764,
#  'performance': 765,
#  'scenario': 766,
#  'insecure': 767,
#  'asymmetric': 768,
#  'judicial': 769,
#  'act': 770,
#  'lax': 771,
#  'enforcement': 772,
#  'FDI': 773,
#  'attract': 774,
#  '2.2.': 775,
#  'policymaking': 776,
#  'adequate': 777,
#  'knowledge': 778,
#  'focal': 779,
#  'country': 780,
#  'Argentina': 781,
#  'unequal': 782,
#  'originate': 783,
#  'colonial': 784,
#  'era': 785,
#  'metropolis': 786,
#  'establishment': 787,
#  'politics': 788,
#  'therefore': 789,
#  'highly': 790,
#  'unstable': 791,
#  'limit': 792,
#  'citizen': 793,
#  'neither': 794,
#  'distant': 795,
#  'rhythm': 796,
#  'automatic': 797,
#  'enjambment': 798,
#  'detection': 799,
#  'four': 800,
#  'sonnet': 801,
#  'Pablo': 802,
#  'Ruiz': 803,
#  'Fabo': 804,
#  'pabloruizfabo@gmail.com': 805,
#  'Lattice': 806,
#  'Lab': 807,
#  'CNRS': 808,
#  'France': 809,
#  'Clara': 810,
#  'Martínez': 811,
#  'Cantón': 812,
#  'cimartinez@flog.uned.es': 813,
#  'Universidad': 814,
#  'Nacional': 815,
#  'de': 816,
#  'Educación': 817,
#  'Distancia': 818,
#  'Spain': 819,
#  'Thierry': 820,
#  'Poibeau': 821,
#  'thierry.poibeau@ens.fr': 822,
#  'syntactic': 823,
#  'unit': 824,
#  'break': 825,
#  'up': 826,
#  'line': 827,
#  'poetry': 828,
#  'Domínguez': 829,
#  'Caparrós': 830,
#  '2000': 831,
#  '103': 832,
#  'give': 833,
#  'rise': 834,
#  'stylistic': 835,
#  'increased': 836,
#  'emphasis': 837,
#  'phrase': 838,
#  'contrast': 839,
#  'double': 840,
#  'enjamb': 841,
#  'García': 842,
#  'Paje': 843,
#  '1991': 844,
#  'configuration': 845,
#  'extensively': 846,
#  'detailed': 847,
#  'author': 848,
#  'overview': 849,
#  'Quilis': 850,
#  '1964': 851,
#  'Paraíso': 852,
#  'Spang': 853,
#  '1983': 854,
#  'description': 855,
#  'Alarcos': 856,
#  '1966': 857,
#  'Senabre': 858,
#  '1982': 859,
#  'Luján': 860,
#  '2006': 861,
#  'Fernández': 862,
#  'scale': 863,
#  'identify': 864,
#  'hundred': 865,
#  'span': 866,
#  'reading': 867,
#  'Moretti': 868,
#  'previously': 869,
#  'need': 870,
#  'software': 871,
#  'natural': 872,
#  'language': 873,
#  'corpus': 874,
#  'approx.': 875,
#  '3750': 876,
#  'ca.': 877,
#  '1000': 878,
#  '15th': 879,
#  '19th': 880,
#  'literature': 881,
#  'debate': 882,
#  'consider': 883,
#  'trigger': 884,
#  'split': 885,
#  'lexical': 886,
#  'criterion': 887,
#  'sufficient': 888,
#  'permit': 889,
#  'object': 890,
#  'current': 891,
#  'systematically': 892,
#  'amount': 893,
#  'helpful': 894,
#  'evidence': 895,
#  'scholar': 896,
#  'claim': 897,
#  'may': 898,
#  'Navarro': 899,
#  '2016': 900,
#  'metrical': 901,
#  'Golden': 902,
#  'Age': 903,
#  'cover': 904,
#  'wide': 905,
#  'period': 906,
#  'abstract': 907,
#  'definition': 908,
#  'evaluation': 909,
#  'finding': 910,
#  'diachronic': 911,
#  'website': 912,
#  'omit': 913,
#  'space': 914,
#  'reason': 915,
#  'Syntactic': 916,
#  'match': 917,
#  'since': 918,
#  'antiquity': 919,
#  'Parry': 920,
#  '1929': 921,
#  'Homer': 922,
#  'Flores': 923,
#  'Gómez': 924,
#  '1988': 925,
#  'early': 926,
#  'classical': 927,
#  'tradition': 928,
#  'encabalgamiento': 929,
#  'pause': 930,
#  'suggest': 931,
#  'poetic': 932,
#  'end': 933,
#  'hemistich': 934,
#  'connect': 935,
#  'unnatural': 936,
#  'cut': 937,
#  'perform': 938,
#  'experiment': 939,
#  'propose': 940,
#  'should': 941,
#  'translate': 942,
#  'term': 943,
#  'léxico': 944,
#  'tmesis': 945,
#  'bound': 946,
#  'sequence': 947,
#  'noun': 948,
#  '+': 949,
#  'adjective': 950,
#  'verb': 951,
#  'adverb': 952,
#  'auxiliary': 953,
#  'sirremático': 954,
#  'Cross-clause': 955,
#  'antecedent': 956,
#  'pronoun': 957,
#  'head': 958,
#  'relative': 959,
#  'clause': 960,
#  'cross-clause': 961,
#  'oracional': 962,
#  'site': 963,
#  'besides': 964,
#  'above': 965,
#  'note': 966,
#  'related': 967,
#  'feel': 968,
#  'unusual': 969,
#  'reader': 970,
#  'less': 971,
#  'pronounce': 972,
#  'than': 973,
#  'differentiate': 974,
#  'proper': 975,
#  'enlace': 976,
#  'expansion': 977,
#  'so': 978,
#  'recitation': 979,
#  'typology': 980,
#  'still': 981,
#  'late': 982,
#  'complementary': 983,
#  'review': 984,
#  'epistemic': 985,
#  'pollution': 986,
#  'rationally': 987,
#  'choose': 988,
#  'expert': 989,
#  'distinguish': 990,
#  'genuine': 991,
#  'charlatan': 992,
#  'common': 993,
#  'sense': 994,
#  'widely': 995,
#  'know': 996,
#  'satisfy': 997,
#  'responsibility': 998,
#  'utilize': 999,
#  ...}

# %%
def get_POS_tags(token,sent_id):
    return df_train[(df_train['sent_id'] == sent_id) & (df_train['normalized_word'] == token)]['POS_tag'].values[0]

# %%
POS_tags=df_train['POS_tag'].unique()
POS_tags
# Out:
# array(['JJ', 'NN', 'CC', ':', 'NNS', 'IN', 'HYPH', 'NNP', ',', 'WRB',
#        'VBP', 'VB', '.', 'WDT', 'PRP', 'DT', 'VBZ', 'VBG', 'RB', 'MD',
#        'PRP$', 'VBN', 'FW', 'SYM', 'VBD', 'TO', 'RP', '-LRB-', '-RRB-',
#        'POS', 'CD', 'EX', 'LS', 'JJR', 'RBR', 'WP$', 'JJS', 'PDT', '``',
#        "''", 'WP', 'NNPS', 'UH', 'RBS', 'GW', '$'], dtype=object)

# %%
df_train.head(10)
# Out:
#               sent_id                                     text          word  \
# 0  GUM_academic_art-1  Aesthetic Appreciation and Spanish Art:     Aesthetic
# 1  GUM_academic_art-1  Aesthetic Appreciation and Spanish Art:  Appreciation
# 2  GUM_academic_art-1  Aesthetic Appreciation and Spanish Art:           and
# 3  GUM_academic_art-1  Aesthetic Appreciation and Spanish Art:       Spanish
# 4  GUM_academic_art-1  Aesthetic Appreciation and Spanish Art:           Art
# 5  GUM_academic_art-1  Aesthetic Appreciation and Spanish Art:             :
# 6  GUM_academic_art-2               Insights from Eye-Tracking      Insights
# 7  GUM_academic_art-2               Insights from Eye-Tracking          from
# 8  GUM_academic_art-2               Insights from Eye-Tracking           Eye
# 9  GUM_academic_art-2               Insights from Eye-Tracking             -
#
#   normalized_word POS_tag head_word_index dependency_relation  \
# 0       aesthetic      JJ               2                amod
# 1    appreciation      NN               0                root
# 2             and      CC               5                  cc
# 3         Spanish      JJ               5                amod
# 4             art      NN               2                conj
# 5               :       :               2               punct
# 6         insight     NNS               0                root
# 7            from      IN               5                case
# 8             eye      NN               5            compound
# 9               -    HYPH               3               punct
#
#    normalized_word_index     head_word                  dep_graph
# 0                      1  appreciation  (appreciation, aesthetic)
# 1                      2          root       (root, appreciation)
# 2                      3           art                 (art, and)
# 3                      4           art             (art, Spanish)
# 4                      5  appreciation        (appreciation, art)
# 5                      6  appreciation          (appreciation, :)
# 6                      1          root            (root, insight)
# 7                      2      tracking           (tracking, from)
# 8                      3      tracking            (tracking, eye)
# 9                      4           eye                   (eye, -)

# %%
get_POS_tags('Spanish', 'GUM_academic_art-1' )
# Out:
# 'JJ'

# %%
POS_mapping = {pos: i for i, pos in enumerate(POS_tags)}
POS_mapping
# Out:
# {'JJ': 0,
#  'NN': 1,
#  'CC': 2,
#  ':': 3,
#  'NNS': 4,
#  'IN': 5,
#  'HYPH': 6,
#  'NNP': 7,
#  ',': 8,
#  'WRB': 9,
#  'VBP': 10,
#  'VB': 11,
#  '.': 12,
#  'WDT': 13,
#  'PRP': 14,
#  'DT': 15,
#  'VBZ': 16,
#  'VBG': 17,
#  'RB': 18,
#  'MD': 19,
#  'PRP$': 20,
#  'VBN': 21,
#  'FW': 22,
#  'SYM': 23,
#  'VBD': 24,
#  'TO': 25,
#  'RP': 26,
#  '-LRB-': 27,
#  '-RRB-': 28,
#  'POS': 29,
#  'CD': 30,
#  'EX': 31,
#  'LS': 32,
#  'JJR': 33,
#  'RBR': 34,
#  'WP$': 35,
#  'JJS': 36,
#  'PDT': 37,
#  '``': 38,
#  "''": 39,
#  'WP': 40,
#  'NNPS': 41,
#  'UH': 42,
#  'RBS': 43,
#  'GW': 44,
#  '$': 45}

# %%
def get_DEP_tags(token, sent_id):
    return df_train[(df_train['sent_id'] == sent_id) & (df_train['normalized_word'] == token)]['dependency_relation'].values[0]

# %%
get_DEP_tags('Spanish', 'GUM_academic_art-1' )
# Out:
# 'amod'

# %%
dep_tags= df_train['dependency_relation'].unique()
dep_tags
# Out:
# array(['amod', 'root', 'cc', 'conj', 'punct', 'case', 'compound', 'nmod',
#        'flat', 'list', 'advmod', 'aux', 'nsubj', 'obl', 'det', 'obj',
#        'advcl:relcl', 'cop', 'acl', 'acl:relcl', 'mark', 'nmod:poss',
#        'advcl', 'nsubj:pass', 'aux:pass', 'nsubj:outer', 'compound:prt',
#        'appos', 'fixed', 'obl:agent', 'csubj', 'dep', 'nmod:tmod',
#        'nummod', 'expl', 'parataxis', 'xcomp', 'cc:preconj', 'ccomp',
#        'det:predet', 'nmod:npmod', 'csubj:outer', 'iobj', 'obl:tmod',
#        'obl:npmod', 'orphan', 'csubj:pass', 'goeswith', 'vocative',
#        'discourse', 'reparandum', 'dislocated'], dtype=object)

# %%
dep_mapping = {dep: i for i, dep in enumerate(dep_tags)}
dep_mapping
# Out:
# {'amod': 0,
#  'root': 1,
#  'cc': 2,
#  'conj': 3,
#  'punct': 4,
#  'case': 5,
#  'compound': 6,
#  'nmod': 7,
#  'flat': 8,
#  'list': 9,
#  'advmod': 10,
#  'aux': 11,
#  'nsubj': 12,
#  'obl': 13,
#  'det': 14,
#  'obj': 15,
#  'advcl:relcl': 16,
#  'cop': 17,
#  'acl': 18,
#  'acl:relcl': 19,
#  'mark': 20,
#  'nmod:poss': 21,
#  'advcl': 22,
#  'nsubj:pass': 23,
#  'aux:pass': 24,
#  'nsubj:outer': 25,
#  'compound:prt': 26,
#  'appos': 27,
#  'fixed': 28,
#  'obl:agent': 29,
#  'csubj': 30,
#  'dep': 31,
#  'nmod:tmod': 32,
#  'nummod': 33,
#  'expl': 34,
#  'parataxis': 35,
#  'xcomp': 36,
#  'cc:preconj': 37,
#  'ccomp': 38,
#  'det:predet': 39,
#  'nmod:npmod': 40,
#  'csubj:outer': 41,
#  'iobj': 42,
#  'obl:tmod': 43,
#  'obl:npmod': 44,
#  'orphan': 45,
#  'csubj:pass': 46,
#  'goeswith': 47,
#  'vocative': 48,
#  'discourse': 49,
#  'reparandum': 50,
#  'dislocated': 51}

# %% [markdown]
# arc_set is a list storing set of arcs in the form of tuples(head_word, dependent_word)

# %% [markdown]
# In feature vector we wil 1st create a binary vector (Z) showing configuration depending on features without considering transitions so it will be of size k= (2*|V|+3*|p| +4*|R|).and then we will just insert this vector Z of size k into a vector T of all transitiosn ahvinf size of 4*k appropriately based on the transitions.

# %% [markdown]
# Transition type:  Left-Arc, Right-Arc, Shift, Reduce

# %%
def create_binary_vector( V,P,R, top_stack_index, first_buffer_index, top_pos_index, first_pos_index, second_pos_index, top_dep_index, top_ldep_index, top_rdep_index, buffer_ldep_index ):
    binary_vector = np.zeros((2*V + 3*P + 4*R)) # Binary vector which are storing the features irrespective of the transitions type
    if top_stack_index is not None:
        binary_vector[top_stack_index] = 1 # TOP(S) feature having size |V|
    if first_buffer_index is not None:
        binary_vector[V + first_buffer_index] = 1 # FIRST(B) feature having size |V|
    if top_pos_index is not None:
        binary_vector[2*V + top_pos_index] =  1 # TOP.POS(S) feature having size |P|
    if first_pos_index is not None:
        binary_vector[2*V + P + first_pos_index] =  1 # FIRST.POS(S) feature having size |P|
    if second_pos_index is not None:
        binary_vector[2*V + 2*P + second_pos_index] =  1 # LOOK.POS(S) feature having size |P|
    if top_dep_index is not None:
        binary_vector[2*V + 3*P + top_dep_index] = 1 # TOP.DEP(S) fature having size  |R|
    if top_ldep_index is not None:
        binary_vector[2*V + 3*P + R + top_ldep_index] = 1 # TOP.LDEP(S) fature having size  |R|
    if top_rdep_index is not None:
        binary_vector[2*V + 3*P + 2*R + top_rdep_index] = 1 # TOP.RDEP(S) fature having size  |R|
    if buffer_ldep_index is not None:
        binary_vector[2*V + 3*P + 3*R + buffer_ldep_index] = 1 # FIRST.LDEP(S) fature having size  |R|

    return binary_vector

# %%
def feature_vector_train(stack, buffer, arc_set, transition_type, sent_id):
    df_1= df_train[df_train['sent_id'] == sent_id] # Filtering dataframe so that it will be easier to access the values corresponding the sent_id of senetence for which we are calculating the feature vectors
    # Initialize feature vectors
    V = len(token_mapping)
    P = len(POS_mapping)
    R = len(dep_mapping)
    feature_vector = np.zeros(4 * (2*V + 3*P + 4*R)) # Feature vector as per tranisiton and configurations


    # Initializing indices corresponding to each feature as None so that if any feature is not found in particular configuration then nothing will assign 1 corresponding to that feature
    top_stack_index, first_buffer_index, top_pos_index, first_pos_index, second_pos_index, top_dep_index, top_ldep_index, top_rdep_index, buffer_ldep_index = (None,) * 9

    # Extract tokens, POS tags, and dependency relations based on stack and buffer
    # TOP = top(S) token, len(stack) is set for greater than 1 means that if there is only sigle token in stack then it must be root and as it is dummy word we will not consider it for feature vector creation
    top_stack_token = stack[-1] if (len(stack)> 1) else None
    top_stack_index = token_mapping[top_stack_token] if top_stack_token else None


    # FIRST = first(B) token
    first_buffer_token = buffer[0] if buffer else None
    first_buffer_index = token_mapping[first_buffer_token] if first_buffer_token else None


    # TOP.POS = POS-Tag of Top(S)
    # First check whether stack is empty or not and top_stack_token exist or not
    if stack and top_stack_token:
        if get_POS_tags(top_stack_token,sent_id):
            top_pos_index = POS_mapping[get_POS_tags(top_stack_token,sent_id)]


    # FIRST.POS = POS-Tag of First(B)
    # first check whether buffer is empty or not
    if buffer:
        if get_POS_tags(first_buffer_token, sent_id):
            first_pos_index = POS_mapping[get_POS_tags(first_buffer_token, sent_id)]


    # LOOK.POS = POS-Tag of first(B-{first(B)})
    if len(buffer) > 1:
        second_token = buffer[1]
        if get_POS_tags(second_token,sent_id):
            second_pos_index = POS_mapping[get_POS_tags(second_token,sent_id)]


    if len(stack) > 0:
        top_word = stack[-1]  # Top word in the stack
        # Check if top_word is a dependent in any arc in arc_set
        for arc in arc_set:
            if arc[1] == top_word and arc[0]!= None:
                top_dep_index = dep_mapping[get_DEP_tags(top_word, sent_id)]
                break


        # Find all arcs where top_word is the head
        top_ldep_arcs = [(head, dependent) for head, dependent in arc_set if head == top_word]
        # Find the left-most word among all dependents based on their positions in the sentence
        if top_ldep_arcs:
            dep_indices_l = [df_1[df_1['normalized_word'] == dependent]['normalized_word_index'].values[0] for _, dependent in top_ldep_arcs]
            sent_left_most_word = df_1[df_1['normalized_word_index'] == min(dep_indices_l)]['normalized_word'].item()
            # If left-most word is found, retrieve its dependency tag
            if sent_left_most_word is not None:
                top_ldep_index = dep_mapping[get_DEP_tags(sent_left_most_word, sent_id)]


        # Find the right-most word connected to the top word in arc_set
        top_rdep_arcs = [(head, dependent) for head, dependent in arc_set if head == top_word]
        # Find the right-most word among all dependents based on their positions in the sentence
        if top_rdep_arcs:
            dep_indices_r = [df_1[df_1['normalized_word'] == dependent]['normalized_word_index'].values[0] for _, dependent in top_rdep_arcs]
            sent_right_most_word = df_1[df_1['normalized_word_index'] == min(dep_indices_r)]['normalized_word'].item()
            # If left-most word is found, retrieve its dependency tag
            if sent_right_most_word is not None:
                top_rdep_index = dep_mapping[get_DEP_tags(sent_right_most_word, sent_id)]


    if len(buffer) > 0:
        # Find all arcs where top_word is the head
        first_word = buffer[0]
        first_ldep_arcs = [(head, dependent) for head, dependent in arc_set if head == first_word]
        # Find the left-most word among all dependents based on their positions in the sentence
        if first_ldep_arcs:
            buffer_dep_indices_l = [df_1[df_1['normalized_word'] == dependent]['normalized_word_index'].values[0] for _, dependent in first_ldep_arcs]
            buffer_left_most_word = df_1[df_1['normalized_word_index'] == min(buffer_dep_indices_l)]['normalized_word'].item()
            # If left-most word is found, retrieve its dependency tag
            if buffer_left_most_word is not None:
              buffer_ldep_index = dep_mapping[get_DEP_tags(buffer_left_most_word, sent_id)]


    binary_vector = create_binary_vector(V, P, R, top_stack_index, first_buffer_index, top_pos_index, first_pos_index, second_pos_index, top_dep_index, top_ldep_index, top_rdep_index, buffer_ldep_index )
    k = binary_vector.shape[0]

    # Inject the binary vector to feature vector based on the transition type
    if transition_type == "LEFT_ARC":  # Left-Arc
        feature_vector[:k] = binary_vector
    elif transition_type == "RIGHT_ARC":  # Right-Arc
        feature_vector[k: 2*k] = binary_vector
    elif transition_type == "SHIFT":  # Shift
        feature_vector[2 * k:3 * k] = binary_vector
    elif transition_type == "REDUCE":  # Reduce
        feature_vector[3 * k:] = binary_vector

    return feature_vector

# %% [markdown]
# I have separately defined functions to perform the execution of each transition. This will take stack, buffer, and arc_set in input and depending on the transition perform certain operations and return the updated stack, buffer, and arc_set. This function only does direction execution, not check the condition. So, we will use this function when we are sure that we have to perform certain transitions.

# %%
def do_LEFT_ARC(stack, buffer, arc_set):
    """ Add top(S) <- first(B) to A, Pop top(S) """
    if stack and buffer:
        head_word = buffer[0]
        dependent_word = stack[-1]
        arc_set.append((head_word, dependent_word))
        stack.pop()
        # print("LEFT_ARC DONE")
    return stack, buffer, arc_set

def do_RIGHT_ARC(stack, buffer, arc_set):
    """ Add top(S) -> first(B) to A, Pop first(B) and Push to S """
    if stack and buffer:
        head_word = stack[-1]
        dependent_word = buffer[0]
        arc_set.append((head_word, dependent_word))
        buffer.pop(0)
        stack.append(dependent_word)
        # print("RIGHT_ARC DONE")
    return stack, buffer, arc_set

def do_REDUCE(stack, buffer, arc_set):
    """  Pop top(S)  """
    if stack:
        stack.pop()
        # print("REDUCE DONE")
    return stack, buffer, arc_set

def do_SHIFT(stack, buffer, arc_set):
    """ Pop first(B) and Push to S  """
    if buffer:
        word = buffer[0]
        buffer.pop(0)
        stack.append(word)
        # print("SHIFT DONE")
    return stack, buffer, arc_set

# %% [markdown]
#  Apply the oracle heuristics to determine the next transition.

# %% [markdown]
# Here D is gold-standard dependency graph which stores all the arcs relationships which is given in training set. While A is arc_set which is storing the arcs which are processed/ discovered till now during training

# %% [markdown]
# Here mapping of transition is done as follows:
#
# LEFR_ARC - 0
#
# RIGHT_ARC - 1
#
# SHIFT - 2
#
# REDUCE - 3

# %%
def oracle(stack, buffer, arc_set, D):
    if stack and buffer:
        top_S= stack[-1]
        first_B = buffer[0]

        # Condition 1: If top(S) <- first(B) in D and head of top(S) is not dicovered means ( * ,top(S) ) not in A, then LEFT-ARC
        if (first_B, top_S) in D and (top_S not in [arc[1] for arc in arc_set]):
            stack, buffer, arc_set = do_LEFT_ARC(stack, buffer, arc_set)
            return 0, stack, buffer, arc_set

        # Condition 2: If top(S) -> first(B) in D, then RIGHT-ARC
        elif (top_S, first_B) in D:
            stack, buffer, arc_set = do_RIGHT_ARC(stack, buffer, arc_set)
            return 1, stack, buffer, arc_set

        # Condition 3: If head of top(S) is dicovered means ( * ,top(S) ) is in A and there exists w in S such that w is not top(S), w <- first(B) in D or w -> first(B) in D, then REDUCE
        elif (top_S in [arc[1] for arc in arc_set]) and any(((w, first_B) in D or (first_B, w) in D) for w in stack if w != top_S):
            stack, buffer, arc_set = do_REDUCE(stack, buffer, arc_set)
            return 3, stack, buffer, arc_set

        # Condition 4:  SHIFT
        else:
            stack, buffer, arc_set = do_SHIFT(stack, buffer, arc_set)
            return 2, stack, buffer, arc_set

    # Condition 4:  SHIFT
    else:
        stack, buffer, arc_set = do_SHIFT(stack, buffer, arc_set)
        return 2, stack, buffer, arc_set

# %% [markdown]
# Function to train a parser on training data

# %% [markdown]
# Online learning algorithm using the oracle for creating a dependency graph.

# %%
def train(df_train, epochs):
    K = epochs  # Number of iterations over training data
    N = len(df_train.groupby('sent_id'))  # Number of instances/sentences in training data
    V = len(token_mapping)
    P = len(POS_mapping)
    R = len(dep_mapping)
    shape = 4 * (2*V + 3*P + 4*R)
    w = np.random.rand(shape).astype(np.float32) # Initialize classifier weights

    # for i in range(1, K + 1):
    for epoch in range(1, K + 1):
        for index, group in tqdm(df_train.groupby('sent_id'), desc=f"Processing Groups - Epoch {epoch}", leave=False):
            S=['root']
            # S = []
            B = group['normalized_word'].tolist()
            arc_set = []
            sent_id = group['sent_id'].iloc[0]
            print(f"Sent_id: {sent_id}")
            D = group['dep_graph'].tolist() # Dependency graph having Gold- standard arc and their tags
            j=0
            while B != []:
                t_classifier = np.argmax(np.dot(w, feature_vector_train(S, B, arc_set, t, sent_id)) for t in ['LEFT-ARC', 'RIGHT-ARC', 'SHIFT', 'REDUCE'])

                S_copy, B_copy, arc_set_copy = deepcopy(S), deepcopy(B), deepcopy(arc_set)
                t_oracle, S_oracle, B_oracle, arc_set_oracle = oracle(S, B, arc_set, D)
                # print(f"classifier transition : {t_classifier},  oracle transition : {t_oracle}")
                if t_classifier != t_oracle:
                  # Updating of weights toward true transition away from wronly predicted transition
                    w += feature_vector_train(S_copy, B_copy, arc_set_copy, t_oracle, sent_id) - feature_vector_train(S_copy, B_copy, arc_set_copy, t_classifier, sent_id)
                    S, B, arc_set = ( S_oracle,B_oracle,arc_set_oracle)
                j = j+1
    return w

# %%
weights = train(df_train, epochs= 2)

# %%
print(weights)

# %%
weights_array = np.array(weights)
# Save the numpy array to a file called "weights.npy"
np.save("weights_model_dep.npy", weights_array)

# %% [markdown]
# # Testing

# %% [markdown]
#   Crating a majority classifier for features like x.yDEP

# %% [markdown]
# Creating a new column having POS Tag of head word and another column which will store pair of POS Tags of head word and corresponding word in the form of (POS_head_word, POS_word)

# %%
df1 = df_train
for index, row in df1.iterrows():
    df_2 = df1[(df1['sent_id'] == row['sent_id'])]
    df_2 = df_2[int(row['head_word_index']) ==  df_2['normalized_word_index']]
    if int(row['head_word_index'])== 0:
      df1.at[index, 'head_word_POS'] = 'root'
    elif not df_2.empty:
        head_word = df_2['POS_tag'].iloc[0]
        df1.at[index, 'head_word_POS'] = head_word
df_train=df1
df_train['POS_Tag_pair']= list(zip(df_train['head_word_POS'], df_train['POS_tag']))
df_train.head(25)
# Out:
#                sent_id                                               text  \
# 0   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 1   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 2   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 3   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 4   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 5   GUM_academic_art-1            Aesthetic Appreciation and Spanish Art:
# 6   GUM_academic_art-2                         Insights from Eye-Tracking
# 7   GUM_academic_art-2                         Insights from Eye-Tracking
# 8   GUM_academic_art-2                         Insights from Eye-Tracking
# 9   GUM_academic_art-2                         Insights from Eye-Tracking
# 10  GUM_academic_art-2                         Insights from Eye-Tracking
# 11  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 12  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 13  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 14  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 15  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 16  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 17  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 18  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 19  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 20  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 21  GUM_academic_art-3  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 22  GUM_academic_art-4  Andrew Beresford a.m.beresford@durham.ac.uk Du...
# 23  GUM_academic_art-4  Andrew Beresford a.m.beresford@durham.ac.uk Du...
# 24  GUM_academic_art-4  Andrew Beresford a.m.beresford@durham.ac.uk Du...
#
#                              word                normalized_word POS_tag  \
# 0                       Aesthetic                      aesthetic      JJ
# 1                    Appreciation                   appreciation      NN
# 2                             and                            and      CC
# 3                         Spanish                        Spanish      JJ
# 4                             Art                            art      NN
# 5                               :                              :       :
# 6                        Insights                        insight     NNS
# 7                            from                           from      IN
# 8                             Eye                            eye      NN
# 9                               -                              -    HYPH
# 10                       Tracking                       tracking      NN
# 11                         Claire                         Claire     NNP
# 12                         Bailey                         Bailey     NNP
# 13                              -                              -    HYPH
# 14                           Ross                           Ross     NNP
# 15  claire.bailey-ross@port.ac.uk  claire.bailey-ross@port.ac.uk     NNP
# 16                     University                     University     NNP
# 17                             of                             of      IN
# 18                     Portsmouth                     Portsmouth     NNP
# 19                              ,                              ,       ,
# 20                         United                          Unite     NNP
# 21                        Kingdom                        Kingdom     NNP
# 22                         Andrew                         Andrew     NNP
# 23                      Beresford                      Beresford     NNP
# 24     a.m.beresford@durham.ac.uk     a.m.beresford@durham.ac.uk     NNP
#
#    head_word_index dependency_relation  normalized_word_index     head_word  \
# 0                2                amod                      1  appreciation
# 1                0                root                      2          root
# 2                5                  cc                      3           art
# 3                5                amod                      4           art
# 4                2                conj                      5  appreciation
# 5                2               punct                      6  appreciation
# 6                0                root                      1          root
# 7                5                case                      2      tracking
# 8                5            compound                      3      tracking
# 9                3               punct                      4           eye
# 10               1                nmod                      5       insight
# 11               0                root                      1          root
# 12               1                flat                      2        Claire
# 13               4               punct                      3          Ross
# 14               2                flat                      4        Bailey
# 15               1                list                      5        Claire
# 16               1                list                      6        Claire
# 17               8                case                      7    Portsmouth
# 18               6                nmod                      8    University
# 19              11               punct                      9       Kingdom
# 20              11                amod                     10       Kingdom
# 21               1                list                     11        Claire
# 22               0                root                      1          root
# 23               1                flat                      2        Andrew
# 24               1                list                      3        Andrew
#
#                                   dep_graph head_word_POS POS_Tag_pair
# 0                 (appreciation, aesthetic)            NN     (NN, JJ)
# 1                      (root, appreciation)          root   (root, NN)
# 2                                (art, and)            NN     (NN, CC)
# 3                            (art, Spanish)            NN     (NN, JJ)
# 4                       (appreciation, art)            NN     (NN, NN)
# 5                         (appreciation, :)            NN      (NN, :)
# 6                           (root, insight)          root  (root, NNS)
# 7                          (tracking, from)            NN     (NN, IN)
# 8                           (tracking, eye)            NN     (NN, NN)
# 9                                  (eye, -)            NN   (NN, HYPH)
# 10                      (insight, tracking)           NNS    (NNS, NN)
# 11                           (root, Claire)          root  (root, NNP)
# 12                         (Claire, Bailey)           NNP   (NNP, NNP)
# 13                                (Ross, -)           NNP  (NNP, HYPH)
# 14                           (Bailey, Ross)           NNP   (NNP, NNP)
# 15  (Claire, claire.bailey-ross@port.ac.uk)           NNP   (NNP, NNP)
# 16                     (Claire, University)           NNP   (NNP, NNP)
# 17                         (Portsmouth, of)           NNP    (NNP, IN)
# 18                 (University, Portsmouth)           NNP   (NNP, NNP)
# 19                             (Kingdom, ,)           NNP     (NNP, ,)
# 20                         (Kingdom, Unite)           NNP   (NNP, NNP)
# 21                        (Claire, Kingdom)           NNP   (NNP, NNP)
# 22                           (root, Andrew)          root  (root, NNP)
# 23                      (Andrew, Beresford)           NNP   (NNP, NNP)
# 24     (Andrew, a.m.beresford@durham.ac.uk)           NNP   (NNP, NNP)

# %% [markdown]
# After creating a new column of POS Tag pair of head word and corresponding word, we will find dependency  relation having maximum frequency for each POS Tag pair.

# %%
pos_freq = df_train.groupby('POS_Tag_pair')['dependency_relation'].value_counts().reset_index(name='count')
pos_majority_rel = pos_freq.loc[pos_freq.groupby('POS_Tag_pair')['count'].idxmax()].reset_index().set_index('POS_Tag_pair')['dependency_relation'].to_dict()

# %%
pos_majority_rel['NNP', 'NNP']
# Out:
# 'flat'

# %% [markdown]
# Finding the head word for each word in the test data so as to used it at time of UAS calculation

# %%
df_test['normalized_word_index'] = df_test.groupby('sent_id').cumcount()+ 1

# %%
df1 = df_test
for index, row in df1.iterrows():
    df_2 = df1[(df1['sent_id'] == row['sent_id'])]
    df_2 = df_2[int(row['head_word_index']) ==  df_2['normalized_word_index']]
    if int(row['head_word_index'])== 0:
      df1.at[index, 'head_word'] = 'root'
    elif not df_2.empty:
        head_word = df_2['normalized_word'].iloc[0]
        df1.at[index, 'head_word'] = head_word
df_test=df1
# df_test.head(25)

# %% [markdown]
# Creating a new column so as to store the (head_word, dependent_word) for each word in each sentences in training data. This will be our True_arc

# %%
df_test['dep_graph_True']= list(zip(df_test['head_word'], df_test['normalized_word']))

# %% [markdown]
# Crearing a feature vector for test using the updated defination of x.yDEP

# %%
def feature_vector_test(stack, buffer, arc_set, transition_type, sent_id):
    df_1= df_test[df_test['sent_id'] == sent_id]
    # Initialize feature vectors
    V = len(token_mapping)
    P = len(POS_mapping)
    R = len(dep_mapping)
    feature_vector = np.zeros(4 * (2*V + 3*P + 4*R)) # Feature vector as per tranisiton and configurations

    # Initializing indices corresponding to each feature as None so that if any feature is not found in particular configuration then nothing will assign 1 corresponding to that feature
    top_stack_index, first_buffer_index, top_pos_index, first_pos_index, second_pos_index, top_dep_index, top_ldep_index, top_rdep_index, buffer_ldep_index = (None,) * 9

    # Extract tokens, POS tags, and dependency relations based on stack and buffer
    # TOP = top(S) token, len(stack) is set for greater than 1 means that if there is only sigle token in stack then it must be root and as it is dummy word we will not consider it for feature vector creation
    top_stack_token = stack[-1] if (len(stack)> 1) else None
    # top_stack_token = stack[-1] if (stack) else None
    top_stack_index = token_mapping[top_stack_token] if top_stack_token else None


    # FIRST = first(B) token
    first_buffer_token = buffer[0] if buffer else None
    first_buffer_index = token_mapping[first_buffer_token] if first_buffer_token else None


    # TOP.POS = POS-Tag of Top(S)
    # First check whether stack is empty or not
    if stack and top_stack_token:
        if get_POS_tags(top_stack_token,sent_id):
            top_pos_index = POS_mapping[get_POS_tags(top_stack_token,sent_id)]


    # FIRST.POS = POS-Tag of First(B)
    # first check whether buffer is empty or not
    if buffer:
        if get_POS_tags(first_buffer_token, sent_id):
            first_pos_index = POS_mapping[get_POS_tags(first_buffer_token, sent_id)]


    # LOOK.POS = POS-Tag of first(B-{first(B)})
    if len(buffer) > 1:
        second_token = buffer[1]
        if get_POS_tags(second_token,sent_id):
            second_pos_index = POS_mapping[get_POS_tags(second_token,sent_id)]


    if len(stack) > 0:
        top_word = stack[-1]  # Top word in the stack
        # Check if top_word is a dependent in any arc in arc_set
        for arc in arc_set:
            if arc[1] == top_word and arc[0]!= None:
                head_word_POS = get_POS_tags(arc[0], sent_id)
                dependent_word_POS = get_POS_tags(arc[1], sent_id)
                top_dep_index = dep_mapping[pos_majority_rel[(head_word_POS, dependent_word_POS)]]
                break


        # Find all arcs where top_word is the head
        top_ldep_arcs = [(head, dependent) for head, dependent in arc_set if head == top_word]
        # Find the left-most word among all dependents based on their positions in the sentence
        if top_ldep_arcs:
            dep_indices_l = [df_1[df_1['normalized_word'] == dependent]['normalized_word_index'].values[0] for _, dependent in top_ldep_arcs]
            sent_left_most_word = df_1[df_1['normalized_word_index'] == min(dep_indices_l)]['normalized_word'].item()
            # If left-most word is found, retrieve its dependency tag
            if sent_left_most_word is not None:
                head_word_POS = get_POS_tags(top_word, sent_id)
                dependent_word_POS = get_POS_tags(sent_left_most_word, sent_id)
                top_ldep_index = dep_mapping[pos_majority_rel[(head_word_POS, dependent_word_POS)]]


        # Find the right-most word connected to the top word in arc_set
        top_rdep_arcs = [(head, dependent) for head, dependent in arc_set if head == top_word]
        # Find the right-most word among all dependents based on their positions in the sentence
        if top_rdep_arcs:
            dep_indices_r = [df_1[df_1['normalized_word'] == dependent]['normalized_word_index'].values[0] for _, dependent in top_rdep_arcs]
            sent_right_most_word = df_1[df_1['normalized_word_index'] == min(dep_indices_r)]['normalized_word'].item()
            # If left-most word is found, retrieve its dependency tag
            if sent_right_most_word is not None:
                head_word_POS = get_POS_tags(top_word, sent_id)
                dependent_word_POS = get_POS_tags(sent_right_most_word, sent_id)
                top_rdep_index = dep_mapping[pos_majority_rel[(head_word_POS, dependent_word_POS)]]


    if len(buffer) > 0:
        # Find all arcs where top_word is the head
        first_word = buffer[0]
        first_ldep_arcs = [(head, dependent) for head, dependent in arc_set if head == first_word]
        # Find the left-most word among all dependents based on their positions in the sentence
        if first_ldep_arcs:
            buffer_dep_indices_l = [df_1[df_1['normalized_word'] == dependent]['normalized_word_index'].values[0] for _, dependent in first_ldep_arcs]
            buffer_left_most_word = df_1[df_1['normalized_word_index'] == min(buffer_dep_indices_l)]['normalized_word'].item()
            # If left-most word is found, retrieve its dependency tag
            if buffer_left_most_word is not None:
              head_word_POS = get_POS_tags(first_word, sent_id)
              dependent_word_POS = get_POS_tags(buffer_left_most_word, sent_id)
              buffer_ldep_index = dep_mapping[pos_majority_rel[(head_word_POS, dependent_word_POS)]]


    binary_vector = create_binary_vector(V, P, R, top_stack_index, first_buffer_index, top_pos_index, first_pos_index, second_pos_index, top_dep_index, top_ldep_index, top_rdep_index, buffer_ldep_index )
    k = binary_vector.shape[0]
    # Inject the binary vector to feature vector based on the transition type
    if transition_type == "LEFT_ARC":  # Left-Arc
        feature_vector[:k] = binary_vector
    elif transition_type == "RIGHT_ARC":  # Right-Arc
        feature_vector[k: 2*k] = binary_vector
    elif transition_type == "SHIFT":  # Shift
        feature_vector[2 * k:3 * k] = binary_vector
    elif transition_type == "REDUCE":  # Reduce
        feature_vector[3 * k:] = binary_vector

    return feature_vector

# %% [markdown]
# Updated function of performinf transition based on certian new heuristics rule given in problem statement for the test data.

# %%
def do_LEFT_ARC_test(stack, buffer, arc_set):
    """ Add top(S) <- first(B) to A, Pop top(S) """
    if stack and buffer:
        head_word = buffer[0]
        dependent_word = stack[-1]
        arc_set.append((head_word, dependent_word))
        stack.pop()
        # print("LEFT_ARC DONE")
        return stack, buffer, arc_set
    elif not stack:
      return do_SHIFT_test(stack, buffer, arc_set)

def do_RIGHT_ARC_test(stack, buffer, arc_set):
    """ Add top(S) -> first(B) to A, Pop first(B) and Push to S """
    if stack and buffer:
        head_word = stack[-1]
        dependent_word = buffer[0]
        arc_set.append((head_word, dependent_word))
        buffer.pop(0)
        stack.append(dependent_word)
        # print("RIGHT_ARC DONE")
        return stack, buffer, arc_set
    elif not stack : # stack is empty then do SHIFT
        return do_SHIFT_test(stack, buffer, arc_set)

def do_REDUCE_test(stack, buffer, arc_set):
    """  Pop top(S)  """
    if stack:
        stack.pop()
        # print("REDUCE DONE")
    return stack, buffer, arc_set

def do_SHIFT_test(stack, buffer, arc_set):
    """ Pop first(B) and Push to S  """
    if buffer:
        word = buffer[0]
        buffer.pop(0)
        stack.append(word)
        # print("SHIFT DONE")
    return stack, buffer, arc_set

# %% [markdown]
# Here mapping of transition is done as follows:
#
# LEFR_ARC - 0, RIGHT_ARC - 1, SHIFT - 2, REDUCE - 3

# %% [markdown]
# Function to calculate UAS score. Here True Arc is a list of Arcs where each arc contains word and their head word as given in test data in form (True_head_word, True_dependent_word). While pred_arc is a list of predicted arcs which is of form ( Pred_head_word, Pred_dependent_word) which are predicted by our model.

# %%
def calculate_UAS_score(sentence, true_arc, pred_arc):
  count = 0
  # Convert list of tuples to a dictionary where key is the dependent and value is the head
  true_arc_dict = {dep: head for head, dep in true_arc}
  pred_arc_dict = {dep: head for head, dep in pred_arc}

  # Iterate over the tokens in the sentence
  for token in sentence:
      true_head = true_arc_dict.get(token)
      pred_head = pred_arc_dict.get(token)
      # print(f"true head: {true_head}, pred_head: {pred_head} ")
      # If the predicted head and true head match, and the token was indeed found as a dependent, count a correct arc
      if true_head is not None and true_head == pred_head:
          count += 1

  return count / len(true_arc) if true_arc else 0  # Prevent division by zero

# %%
weights_train = np.load("weights_model_dep.npy")
print(weights_train)
# Out:
# [0.28697222 0.27081656 0.22608441 ... 0.16209386 0.7112532  0.3578552 ]

# %%
def test(df_test):
    output_test = {
    'sent_id': [],
    'token number': [],
    'word': [],
    'predicted_head_token': []
    }

    N = len(df_test.groupby('sent_id'))  # Number of instances/sentences in testing data
    V = len(token_mapping)
    P = len(POS_mapping)
    R = len(dep_mapping)
    shape = 4 * (2*V + 3*P + 4*R)
    avg_UAS_score = []
    for index, group in df_test.groupby('sent_id'):
        S=['root']
        # S = []
        B = group['normalized_word'].tolist()
        sentence = group['normalized_word'].tolist()
        arc_set = []
        sent_id = group['sent_id'].iloc[0]
        True_arc = group['dep_graph_True'].tolist()
        j=0
        while B != []:
            # print(f"Instance of senetence: {j}")
            t_classifier = np.argmax(np.dot(weights_train, feature_vector_test(S, B, arc_set, t, sent_id)) for t in ['LEFT-ARC', 'RIGHT-ARC', 'SHIFT', 'REDUCE'])
            # print(f"classifier transition : {t_classifier}")
            if t_classifier == 0:
                S, B, arc_set = do_LEFT_ARC_test(S, B, arc_set)
            elif t_classifier == 1:
                S, B, arc_set = do_RIGHT_ARC_test(S, B, arc_set)
            elif t_classifier == 2:
                S, B, arc_set = do_SHIFT_test(S, B, arc_set)
            elif t_classifier == 3:
                S, B, arc_set = do_REDUCE_test(S, B, arc_set)
            j = j+1

        UAS_score = calculate_UAS_score(sentence, True_arc, arc_set)
        print(f"\n Testing Example sent_id : {sent_id}, UAS Score: {UAS_score}")
        avg_UAS_score.append(UAS_score)
        pred_arc_dict = {dep: head for head, dep in arc_set}
        # print(arc_dict)
        # Store the test output for each word in the sentence
        print(f"sentence: {sentence}, arc_set: {arc_set}")
        i=1
        for word in sentence:
            output_test['sent_id'].append(sent_id)
            output_test['token number'].append(i)
            i = i+1
            output_test['word'].append(word)
            predicted_head = pred_arc_dict.get(word)  # Using get() avoids KeyError if the word is not found
            # print(f"predicted head: {predicted_head}")
            output_test['predicted_head_token'].append(predicted_head)

    return output_test, avg_UAS_score

# %%
test_output, avg_UAS_score = test(df_test)
print(f"Average UAS Score over Test Data: {np.mean(avg_UAS_score)}")
# Out:
#  Testing Example sent_id : GUM_academic_discrimination-1, UAS Score: 0.36363636363636365
# sentence: ['the', 'prevalence', 'of', 'discrimination', 'across', 'racial', 'group', 'in', 'contemporary', 'America', ':'], arc_set: [('the', 'root'), ('prevalence', 'the'), ('of', 'prevalence'), ('discrimination', 'of'), ('across', 'discrimination'), ('racial', 'across'), ('group', 'racial'), ('in', 'group'), ('contemporary', 'in'), ('America', 'contemporary'), (':', 'America')]
#
#  Testing Example sent_id : GUM_academic_discrimination-10, UAS Score: 0.2962962962962963
# sentence: ['what', 'also', 'should', 'not', 'be', 'lose', 'in', 'discussion', 'of', 'discrimination', 'be', 'the', 'grow', 'push', 'to', 'implement', 'social', 'policy', 'aim', 'at', 'reduce', 'the', 'occurrence', 'of', 'discriminatory', 'practice', '.'], arc_set: [('what', 'root'), ('also', 'what'), ('should', 'also'), ('not', 'should'), ('be', 'not'), ('lose', 'be'), ('in', 'lose'), ('discussion', 'in'), ('of', 'discussion'), ('discrimination', 'of'), ('be', 'discrimination'), ('the', 'be'), ('grow', 'the'), ('push', 'grow'), ('to', 'push'), ('implement', 'to'), ('social', 'implement'), ('policy', 'social'), ('aim', 'policy'), ('at', 'aim'), ('reduce', 'at'), ('the', 'reduce'), ('occurrence', 'the'), ('of', 'occurrence'), ('discriminatory', 'of'), ('practice', 'discriminatory'), ('.', 'practice')]
#
#  Testing Example sent_id : GUM_academic_discrimination-11, UAS Score: 0.37142857142857144
# sentence: ['mandatory', 'diversity', 'training', 'in', 'professional', 'setting', ',', 'for', 'example', ',', 'be', 'intend', 'to', 'reduce', 'bias', 'in', 'the', 'workplace', 'by', 'increase', 'the', 'awareness', 'of', 'employee', 'regard', 'the', 'challenge', 'face', 'minority', 'group', 'member', '.', '[', '12', ']'], arc_set: [('mandatory', 'root'), ('diversity', 'mandatory'), ('training', 'diversity'), ('in', 'training'), ('professional', 'in'), ('setting', 'professional'), (',', 'setting'), ('for', ','), ('example', 'for'), (',', 'example'), ('be', ','), ('intend', 'be'), ('to', 'intend'), ('reduce', 'to'), ('bias', 'reduce'), ('in', 'bias'), ('the', 'in'), ('workplace', 'the'), ('by', 'workplace'), ('increase', 'by'), ('the', 'increase'), ('awareness', 'the'), ('of', 'awareness'), ('employee', 'of'), ('regard', 'employee'), ('the', 'regard'), ('challenge', 'the'), ('face', 'challenge'), ('minority', 'face'), ('group', 'minority'), ('member', 'group'), ('.', 'member'), ('[', '.'), ('12', '['), (']', '12')]
#
#  Testing Example sent_id : GUM_academic_discrimination-12, UAS Score: 0.23333333333333334
# sentence: ['indeed', ',', 'the', 'implementation', 'of', 'certain', 'policy', 'be', 'root', 'in', 'the', 'assumption', 'that', 'discrimination', 'and', 'bias', 'be', ',', 'at', 'least', 'to', 'some', 'appreciable', 'amount', ',', 'present', 'in', 'modern', 'society', '.'], arc_set: [('indeed', 'root'), (',', 'indeed'), ('the', ','), ('implementation', 'the'), ('of', 'implementation'), ('certain', 'of'), ('policy', 'certain'), ('be', 'policy'), ('root', 'be'), ('in', 'root'), ('the', 'in'), ('assumption', 'the'), ('that', 'assumption'), ('discrimination', 'that'), ('and', 'discrimination'), ('bias', 'and'), ('be', 'bias'), (',', 'be'), ('at', ','), ('least', 'at'), ('to', 'least'), ('some', 'to'), ('appreciable', 'some'), ('amount', 'appreciable'), (',', 'amount'), ('present', ','), ('in', 'present'), ('modern', 'in'), ('society', 'modern'), ('.', 'society')]
#
#  Testing Example sent_id : GUM_academic_discrimination-13, UAS Score: 0.2857142857142857
# sentence: ['even', 'so', ',', 'estimate', 'of', 'the', 'prevalence', 'of', 'perceive', 'discrimination', 'remain', 'rare', '(', 'see', '[', '13', '-', '14', ']', ')', '.'], arc_set: [('even', 'root'), ('so', 'even'), (',', 'so'), ('estimate', ','), ('of', 'estimate'), ('the', 'of'), ('prevalence', 'the'), ('of', 'prevalence'), ('perceive', 'of'), ('discrimination', 'perceive'), ('remain', 'discrimination'), ('rare', 'remain'), ('(', 'rare'), ('see', '('), ('[', 'see'), ('13', '['), ('-', '13'), ('14', '-'), (']', '14'), (')', ']'), ('.', ')')]
#
#  Testing Example sent_id : GUM_academic_discrimination-14, UAS Score: 0.38
# sentence: ['at', 'least', 'one', 'prior', 'study', 'by', 'Kessler', 'and', 'colleague', '[', '15', ']', ',', 'however', ',', 'use', 'measure', 'of', 'perceive', 'discrimination', 'in', 'a', 'large', 'American', 'sample', ',', 'report', 'that', 'approximately', '33', '%', 'of', 'respondent', 'report', 'some', 'form', 'of', 'discrimination', '(', 'see', 'also', ',', 'Gibbons', 'et', 'al.', '[', '4', ']', ')', '.'], arc_set: [('at', 'root'), ('least', 'at'), ('one', 'least'), ('prior', 'one'), ('study', 'prior'), ('by', 'study'), ('Kessler', 'by'), ('and', 'Kessler'), ('colleague', 'and'), ('[', 'colleague'), ('15', '['), (']', '15'), (',', ']'), ('however', ','), (',', 'however'), ('use', ','), ('measure', 'use'), ('of', 'measure'), ('perceive', 'of'), ('discrimination', 'perceive'), ('in', 'discrimination'), ('a', 'in'), ('large', 'a'), ('American', 'large'), ('sample', 'American'), (',', 'sample'), ('report', ','), ('that', 'report'), ('approximately', 'that'), ('33', 'approximately'), ('%', '33'), ('of', '%'), ('respondent', 'of'), ('report', 'respondent'), ('some', 'report'), ('form', 'some'), ('of', 'form'), ('discrimination', 'of'), ('(', 'discrimination'), ('see', '('), ('also', 'see'), (',', 'also'), ('Gibbons', ','), ('et', 'Gibbons'), ('al.', 'et'), ('[', 'al.'), ('4', '['), (']', '4'), (')', ']'), ('.', ')')]
#
#  Testing Example sent_id : GUM_academic_discrimination-15, UAS Score: 0.36666666666666664
# sentence: ['the', 'current', 'study', 'seek', 'to', 'build', 'on', 'this', 'research', 'by', 'estimate', 'the', 'prevalence', 'of', 'discrimination', 'experience', 'among', 'a', 'large', ',', 'nationally', 'representative', 'sample', 'of', 'adult', 'from', 'the', 'Unite', 'State', '.'], arc_set: [('the', 'root'), ('current', 'the'), ('study', 'current'), ('seek', 'study'), ('to', 'seek'), ('build', 'to'), ('on', 'build'), ('this', 'on'), ('research', 'this'), ('by', 'research'), ('estimate', 'by'), ('the', 'estimate'), ('prevalence', 'the'), ('of', 'prevalence'), ('discrimination', 'of'), ('experience', 'discrimination'), ('among', 'experience'), ('a', 'among'), ('large', 'a'), (',', 'large'), ('nationally', ','), ('representative', 'nationally'), ('sample', 'representative'), ('of', 'sample'), ('adult', 'of'), ('from', 'adult'), ('the', 'from'), ('Unite', 'the'), ('State', 'Unite'), ('.', 'State')]
#
#  Testing Example sent_id : GUM_academic_discrimination-16, UAS Score: 0.23076923076923078
# sentence: ['additionally', ',', 'the', 'analysis', 'address', 'the', 'perceive', 'reason', 'for', 'report', 'discrimination', 'experience', '.'], arc_set: [('additionally', 'root'), (',', 'additionally'), ('the', ','), ('analysis', 'the'), ('address', 'analysis'), ('the', 'address'), ('perceive', 'the'), ('reason', 'perceive'), ('for', 'reason'), ('report', 'for'), ('discrimination', 'report'), ('experience', 'discrimination'), ('.', 'experience')]
#
#  Testing Example sent_id : GUM_academic_discrimination-17, UAS Score: 0.25
# sentence: ['reason', 'for', 'discrimination', '.'], arc_set: [('reason', 'root'), ('for', 'reason'), ('discrimination', 'for'), ('.', 'discrimination')]
#
#  Testing Example sent_id : GUM_academic_discrimination-18, UAS Score: 0.3125
# sentence: ['all', 'respondent', 'who', 'indicate', 'they', 'be', 'discriminate', 'against', '—', 'specifically', ',', 'that', 'who', 'respond', 'with', 'sometimes', 'or', 'often', 'to', 'the', 'perceive', 'discrimination', 'measure', 'describe', 'above', '—', 'be', 'ask', 'the', 'follow', 'question', ':'], arc_set: [('all', 'root'), ('respondent', 'all'), ('who', 'respondent'), ('indicate', 'who'), ('they', 'indicate'), ('be', 'they'), ('discriminate', 'be'), ('against', 'discriminate'), ('—', 'against'), ('specifically', '—'), (',', 'specifically'), ('that', ','), ('who', 'that'), ('respond', 'who'), ('with', 'respond'), ('sometimes', 'with'), ('or', 'sometimes'), ('often', 'or'), ('to', 'often'), ('the', 'to'), ('perceive', 'the'), ('discrimination', 'perceive'), ('measure', 'discrimination'), ('describe', 'measure'), ('above', 'describe'), ('—', 'above'), ('be', '—'), ('ask', 'be'), ('the', 'ask'), ('follow', 'the'), ('question', 'follow'), (':', 'question')]
#
#  Testing Example sent_id : GUM_academic_discrimination-19, UAS Score: 0.21428571428571427
# sentence: ["''", 'what', 'do', 'you', 'think', 'be', 'the', 'main', 'reason', 'for', 'this', 'experience', '?', "''"], arc_set: [("''", 'root'), ('what', "''"), ('do', 'what'), ('you', 'do'), ('think', 'you'), ('be', 'think'), ('the', 'be'), ('main', 'the'), ('reason', 'main'), ('for', 'reason'), ('this', 'for'), ('experience', 'this'), ('?', 'experience'), ("''", '?')]
#
#  Testing Example sent_id : GUM_academic_discrimination-2, UAS Score: 0.375
# sentence: ['result', 'from', 'a', 'nationally', 'representative', 'sample', 'of', 'adult'], arc_set: [('result', 'root'), ('from', 'result'), ('a', 'from'), ('nationally', 'a'), ('representative', 'nationally'), ('sample', 'representative'), ('of', 'sample'), ('adult', 'of')]
#
#  Testing Example sent_id : GUM_academic_discrimination-20, UAS Score: 0.36363636363636365
# sentence: ['respondent', 'be', 'allow', 'to', 'choose', 'one', 'response', 'from', '11', 'category', '.'], arc_set: [('respondent', 'root'), ('be', 'respondent'), ('allow', 'be'), ('to', 'allow'), ('choose', 'to'), ('one', 'choose'), ('response', 'one'), ('from', 'response'), ('11', 'from'), ('category', '11'), ('.', 'category')]
#
#  Testing Example sent_id : GUM_academic_discrimination-21, UAS Score: 0.3157894736842105
# sentence: ['for', 'the', 'present', 'analysis', ',', 'this', 'response', 'be', 'recode', 'into', 'nine', 'mutually', 'exclusive', 'category', 'capture', 'the', 'follow', 'option', ':'], arc_set: [('for', 'root'), ('the', 'for'), ('present', 'the'), ('analysis', 'present'), (',', 'analysis'), ('this', ','), ('response', 'this'), ('be', 'response'), ('recode', 'be'), ('into', 'recode'), ('nine', 'into'), ('mutually', 'nine'), ('exclusive', 'mutually'), ('category', 'exclusive'), ('capture', 'category'), ('the', 'capture'), ('follow', 'the'), ('option', 'follow'), (':', 'option')]
#
#  Testing Example sent_id : GUM_academic_discrimination-22, UAS Score: 0.14285714285714285
# sentence: ['race', '/', 'ancestry', '/', 'skin', 'color', ';'], arc_set: [('race', 'root'), ('/', 'race'), ('ancestry', '/'), ('/', 'ancestry'), ('skin', '/'), ('color', 'skin'), (';', 'color')]
#
#  Testing Example sent_id : GUM_academic_discrimination-23, UAS Score: 0.0
# sentence: ['gender', ';'], arc_set: [('gender', 'root'), (';', 'gender')]
#
#  Testing Example sent_id : GUM_academic_discrimination-24, UAS Score: 0.0
# sentence: ['age', ';'], arc_set: [('age', 'root'), (';', 'age')]
#
#  Testing Example sent_id : GUM_academic_discrimination-25, UAS Score: 0.0
# sentence: ['religion', ';'], arc_set: [('religion', 'root'), (';', 'religion')]
#
#  Testing Example sent_id : GUM_academic_discrimination-26, UAS Score: 0.25
# sentence: ['height', 'or', 'weight', ';'], arc_set: [('height', 'root'), ('or', 'height'), ('weight', 'or'), (';', 'weight')]
#
#  Testing Example sent_id : GUM_academic_discrimination-27, UAS Score: 0.3333333333333333
# sentence: ['sexual', 'orientation', ';'], arc_set: [('sexual', 'root'), ('orientation', 'sexual'), (';', 'orientation')]
#
#  Testing Example sent_id : GUM_academic_discrimination-28, UAS Score: 0.25
# sentence: ['education', 'or', 'income', ';'], arc_set: [('education', 'root'), ('or', 'education'), ('income', 'or'), (';', 'income')]
#
#  Testing Example sent_id : GUM_academic_discrimination-29, UAS Score: 0.3333333333333333
# sentence: ['physical', 'disability', ';'], arc_set: [('physical', 'root'), ('disability', 'physical'), (';', 'disability')]
#
#  Testing Example sent_id : GUM_academic_discrimination-3, UAS Score: 0.0
# sentence: ['introduction', '.'], arc_set: [('introduction', 'root'), ('.', 'introduction')]
#
#  Testing Example sent_id : GUM_academic_discrimination-30, UAS Score: 0.3333333333333333
# sentence: ['and', 'other', '.'], arc_set: [('and', 'root'), ('other', 'and'), ('.', 'other')]
#
#  Testing Example sent_id : GUM_academic_discrimination-31, UAS Score: 0.3793103448275862
# sentence: ['the', 'follow', 'category', 'from', 'the', 'original', 'questionnaire', 'be', 'collapse', 'into', 'one', 'category', 'for', 'the', 'analysis', ':', 'race', ';', 'ancestry', 'or', 'national', 'origin', ';', 'and', 'shade', 'of', 'skin', 'color', '.'], arc_set: [('the', 'root'), ('follow', 'the'), ('category', 'follow'), ('from', 'category'), ('the', 'from'), ('original', 'the'), ('questionnaire', 'original'), ('be', 'questionnaire'), ('collapse', 'be'), ('into', 'collapse'), ('one', 'into'), ('category', 'one'), ('for', 'category'), ('the', 'for'), ('analysis', 'the'), (':', 'analysis'), ('race', ':'), (';', 'race'), ('ancestry', ';'), ('or', 'ancestry'), ('national', 'or'), ('origin', 'national'), (';', 'origin'), ('and', ';'), ('shade', 'and'), ('of', 'shade'), ('skin', 'of'), ('color', 'skin'), ('.', 'color')]
#
#  Testing Example sent_id : GUM_academic_discrimination-32, UAS Score: 0.2972972972972973
# sentence: ['additionally', ',', 'because', 'this', 'question', 'be', 'only', 'ask', 'of', 'respondent', 'who', 'report', 'prior', 'discrimination', 'experience', ',', 'the', 'build', '-', 'in', 'skip', 'pattern', 'result', 'in', 'a', 'large', 'number', 'of', 'case', 'score', 'as', 'missing', '(', 'legitimate', 'skip', ')', '.'], arc_set: [('additionally', 'root'), (',', 'additionally'), ('because', ','), ('this', 'because'), ('question', 'this'), ('be', 'question'), ('only', 'be'), ('ask', 'only'), ('of', 'ask'), ('respondent', 'of'), ('who', 'respondent'), ('report', 'who'), ('prior', 'report'), ('discrimination', 'prior'), ('experience', 'discrimination'), (',', 'experience'), ('the', ','), ('build', 'the'), ('-', 'build'), ('in', '-'), ('skip', 'in'), ('pattern', 'skip'), ('result', 'pattern'), ('in', 'result'), ('a', 'in'), ('large', 'a'), ('number', 'large'), ('of', 'number'), ('case', 'of'), ('score', 'case'), ('as', 'score'), ('missing', 'as'), ('(', 'missing'), ('legitimate', '('), ('skip', 'legitimate'), (')', 'skip'), ('.', ')')]
#
#  Testing Example sent_id : GUM_academic_discrimination-33, UAS Score: 0.3333333333333333
# sentence: ['respondent', 'race', '.'], arc_set: [('respondent', 'root'), ('race', 'respondent'), ('.', 'race')]
#
#  Testing Example sent_id : GUM_academic_discrimination-34, UAS Score: 0.14285714285714285
# sentence: ['because', 'a', 'race', 'variable', 'be', 'not', 'available', 'from', 'the', 'Wave', '4', 'interview', ',', 'we', 'use', 'the', 'racial', 'category', 'report', 'by', 'the', 'respondent', 'during', 'the', 'Wave', '1', 'interview', '.'], arc_set: [('because', 'root'), ('a', 'because'), ('race', 'a'), ('variable', 'race'), ('be', 'variable'), ('not', 'be'), ('available', 'not'), ('from', 'available'), ('the', 'from'), ('Wave', 'the'), ('4', 'Wave'), ('interview', '4'), (',', 'interview'), ('we', ','), ('use', 'we'), ('the', 'use'), ('racial', 'the'), ('category', 'racial'), ('report', 'category'), ('by', 'report'), ('the', 'by'), ('respondent', 'the'), ('during', 'respondent'), ('the', 'during'), ('Wave', 'the'), ('1', 'Wave'), ('interview', '1'), ('.', 'interview')]
#
#  Testing Example sent_id : GUM_academic_discrimination-35, UAS Score: 0.15
# sentence: ['Wave', '1', 'race', '—', 'rather', 'than', ',', 'say', ',', 'Wave', '3', 'race', '—', 'be', 'use', 'to', 'preserve', 'case', 'count', '.'], arc_set: [('Wave', 'root'), ('1', 'Wave'), ('race', '1'), ('—', 'race'), ('rather', '—'), ('than', 'rather'), (',', 'than'), ('say', ','), (',', 'say'), ('Wave', ','), ('3', 'Wave'), ('race', '3'), ('—', 'race'), ('be', '—'), ('use', 'be'), ('to', 'use'), ('preserve', 'to'), ('case', 'preserve'), ('count', 'case'), ('.', 'count')]
#
#  Testing Example sent_id : GUM_academic_discrimination-36, UAS Score: 0.2222222222222222
# sentence: ['the', 'logic', 'be', 'that', '(', 'nearly', ')', 'all', 'Wave', '4', 'respondent', 'appear', 'in', 'the', 'Wave', '1', 'sample', ',', 'but', 'not', 'all', 'would', 'have', 'be', 'interview', 'at', 'Wave', '3', 'due', 'to', 'differential', 'pattern', 'of', 'temporary', 'attrition', '.'], arc_set: [('the', 'root'), ('logic', 'the'), ('be', 'logic'), ('that', 'be'), ('(', 'that'), ('nearly', '('), (')', 'nearly'), ('all', ')'), ('Wave', 'all'), ('4', 'Wave'), ('respondent', '4'), ('appear', 'respondent'), ('in', 'appear'), ('the', 'in'), ('Wave', 'the'), ('1', 'Wave'), ('sample', '1'), (',', 'sample'), ('but', ','), ('not', 'but'), ('all', 'not'), ('would', 'all'), ('have', 'would'), ('be', 'have'), ('interview', 'be'), ('at', 'interview'), ('Wave', 'at'), ('3', 'Wave'), ('due', '3'), ('to', 'due'), ('differential', 'to'), ('pattern', 'differential'), ('of', 'pattern'), ('temporary', 'of'), ('attrition', 'temporary'), ('.', 'attrition')]
#
#  Testing Example sent_id : GUM_academic_discrimination-37, UAS Score: 0.2647058823529412
# sentence: ['respondent', 'be', 'ask', 'to', 'indicate', 'their', 'race', 'from', 'among', 'the', 'follow', 'category', ':', 'White', ';', 'Black', 'or', 'African', 'American', ';', 'Hispanic', ';', 'American', 'Indian', 'or', 'Native', 'American', ';', 'and', 'Asian', 'or', 'Pacific', 'Islander', '.'], arc_set: [('respondent', 'root'), ('be', 'respondent'), ('ask', 'be'), ('to', 'ask'), ('indicate', 'to'), ('their', 'indicate'), ('race', 'their'), ('from', 'race'), ('among', 'from'), ('the', 'among'), ('follow', 'the'), ('category', 'follow'), (':', 'category'), ('White', ':'), (';', 'White'), ('Black', ';'), ('or', 'Black'), ('African', 'or'), ('American', 'African'), (';', 'American'), ('Hispanic', ';'), (';', 'Hispanic'), ('American', ';'), ('Indian', 'American'), ('or', 'Indian'), ('Native', 'or'), ('American', 'Native'), (';', 'American'), ('and', ';'), ('Asian', 'and'), ('or', 'Asian'), ('Pacific', 'or'), ('Islander', 'Pacific'), ('.', 'Islander')]
#
#  Testing Example sent_id : GUM_academic_discrimination-38, UAS Score: 0.3125
# sentence: ['respondent', 'be', 'provide', 'the', 'opportunity', 'to', 'select', 'more', 'than', 'one', 'race', ',', 'and', 'that', 'who', 'do', 'be', 'ask', 'a', 'follow', '-', 'up', 'question', 'regard', 'which', 'category', 'well', 'describe', 'their', 'racial', 'background', '.'], arc_set: [('respondent', 'root'), ('be', 'respondent'), ('provide', 'be'), ('the', 'provide'), ('opportunity', 'the'), ('to', 'opportunity'), ('select', 'to'), ('more', 'select'), ('than', 'more'), ('one', 'than'), ('race', 'one'), (',', 'race'), ('and', ','), ('that', 'and'), ('who', 'that'), ('do', 'who'), ('be', 'do'), ('ask', 'be'), ('a', 'ask'), ('follow', 'a'), ('-', 'follow'), ('up', '-'), ('question', 'up'), ('regard', 'question'), ('which', 'regard'), ('category', 'which'), ('well', 'category'), ('describe', 'well'), ('their', 'describe'), ('racial', 'their'), ('background', 'racial'), ('.', 'background')]
#
#  Testing Example sent_id : GUM_academic_discrimination-39, UAS Score: 0.2857142857142857
# sentence: ['in', 'the', 'current', 'study', ',', 'that', 'respondent', 'who', 'indicate', 'more', 'than', 'one', 'race', 'be', 'code', 'as', "''", 'mix', 'race', "''", '.'], arc_set: [('in', 'root'), ('the', 'in'), ('current', 'the'), ('study', 'current'), (',', 'study'), ('that', ','), ('respondent', 'that'), ('who', 'respondent'), ('indicate', 'who'), ('more', 'indicate'), ('than', 'more'), ('one', 'than'), ('race', 'one'), ('be', 'race'), ('code', 'be'), ('as', 'code'), ("''", 'as'), ('mix', "''"), ('race', 'mix'), ("''", 'race'), ('.', "''")]
#
#  Testing Example sent_id : GUM_academic_discrimination-4, UAS Score: 0.3333333333333333
# sentence: ['personal', 'experience', 'of', 'discrimination', 'and', 'bias', 'have', 'be', 'the', 'focus', 'of', 'much', 'social', 'science', 'research', '.', '[', '1', '-', '3', ']'], arc_set: [('personal', 'root'), ('experience', 'personal'), ('of', 'experience'), ('discrimination', 'of'), ('and', 'discrimination'), ('bias', 'and'), ('have', 'bias'), ('be', 'have'), ('the', 'be'), ('focus', 'the'), ('of', 'focus'), ('much', 'of'), ('social', 'much'), ('science', 'social'), ('research', 'science'), ('.', 'research'), ('[', '.'), ('1', '['), ('-', '1'), ('3', '-'), (']', '3')]
#
#  Testing Example sent_id : GUM_academic_discrimination-40, UAS Score: 0.3333333333333333
# sentence: ['demographic', 'variable', '.'], arc_set: [('demographic', 'root'), ('variable', 'demographic'), ('.', 'variable')]
#
#  Testing Example sent_id : GUM_academic_discrimination-41, UAS Score: 0.2777777777777778
# sentence: ['to', 'provide', 'information', 'on', 'the', 'analytical', 'sample', 'as', 'a', 'whole', ',', 'two', 'additional', 'demographic', 'variable', 'be', 'include', '.'], arc_set: [('to', 'root'), ('provide', 'to'), ('information', 'provide'), ('on', 'information'), ('the', 'on'), ('analytical', 'the'), ('sample', 'analytical'), ('as', 'sample'), ('a', 'as'), ('whole', 'a'), (',', 'whole'), ('two', ','), ('additional', 'two'), ('demographic', 'additional'), ('variable', 'demographic'), ('be', 'variable'), ('include', 'be'), ('.', 'include')]
#
#  Testing Example sent_id : GUM_academic_discrimination-42, UAS Score: 0.24242424242424243
# sentence: ['first', ',', 'age', 'be', 'a', 'continuous', 'measure', 'create', 'by', 'subtract', 'the', 'year', 'of', 'the', 'respondent', "'s", 'birth', '(', 'obtain', 'from', 'Wave', '1', ')', 'from', 'the', 'year', 'of', 'the', 'interview', 'at', 'Wave', '4', '.'], arc_set: [('first', 'root'), (',', 'first'), ('age', ','), ('be', 'age'), ('a', 'be'), ('continuous', 'a'), ('measure', 'continuous'), ('create', 'measure'), ('by', 'create'), ('subtract', 'by'), ('the', 'subtract'), ('year', 'the'), ('of', 'year'), ('the', 'of'), ('respondent', 'the'), ("'s", 'respondent'), ('birth', "'s"), ('(', 'birth'), ('obtain', '('), ('from', 'obtain'), ('Wave', 'from'), ('1', 'Wave'), (')', '1'), ('from', ')'), ('the', 'from'), ('year', 'the'), ('of', 'year'), ('the', 'of'), ('interview', 'the'), ('at', 'interview'), ('Wave', 'at'), ('4', 'Wave'), ('.', '4')]
#
#  Testing Example sent_id : GUM_academic_discrimination-43, UAS Score: 0.2413793103448276
# sentence: ['second', ',', 'sex', 'be', 'dichotomously', 'code', 'base', 'on', 'the', 'self', '-', 'report', 'sex', 'of', 'the', 'respondent', 'at', 'Wave', '4', '(', '0', '=', 'female', 'and', '1', '=', 'male', ')', '.'], arc_set: [('second', 'root'), (',', 'second'), ('sex', ','), ('be', 'sex'), ('dichotomously', 'be'), ('code', 'dichotomously'), ('base', 'code'), ('on', 'base'), ('the', 'on'), ('self', 'the'), ('-', 'self'), ('report', '-'), ('sex', 'report'), ('of', 'sex'), ('the', 'of'), ('respondent', 'the'), ('at', 'respondent'), ('Wave', 'at'), ('4', 'Wave'), ('(', '4'), ('0', '('), ('=', '0'), ('female', '='), ('and', 'female'), ('1', 'and'), ('=', '1'), ('male', '='), (')', 'male'), ('.', ')')]
#
#  Testing Example sent_id : GUM_academic_discrimination-44, UAS Score: 0.3333333333333333
# sentence: ['analytical', 'plan', '.'], arc_set: [('analytical', 'root'), ('plan', 'analytical'), ('.', 'plan')]
#
#  Testing Example sent_id : GUM_academic_discrimination-45, UAS Score: 0.375
# sentence: ['our', 'exploratory', 'study', 'include', 'three', 'basic', 'step', '.'], arc_set: [('our', 'root'), ('exploratory', 'our'), ('study', 'exploratory'), ('include', 'study'), ('three', 'include'), ('basic', 'three'), ('step', 'basic'), ('.', 'step')]
#
#  Testing Example sent_id : GUM_academic_discrimination-46, UAS Score: 0.2857142857142857
# sentence: ['first', ',', 'summary', 'statistic', 'of', 'the', 'study', 'variable', 'and', 'racial', 'category', 'be', 'produce', '.'], arc_set: [('first', 'root'), (',', 'first'), ('summary', ','), ('statistic', 'summary'), ('of', 'statistic'), ('the', 'of'), ('study', 'the'), ('variable', 'study'), ('and', 'variable'), ('racial', 'and'), ('category', 'racial'), ('be', 'category'), ('produce', 'be'), ('.', 'produce')]
#
#  Testing Example sent_id : GUM_academic_discrimination-47, UAS Score: 0.2777777777777778
# sentence: ['second', ',', 'we', 'examine', 'the', 'relative', 'proportion', 'of', 'the', 'two', 'discrimination', 'experience', 'measure', 'across', 'each', 'racial', 'category', '.'], arc_set: [('second', 'root'), (',', 'second'), ('we', ','), ('examine', 'we'), ('the', 'examine'), ('relative', 'the'), ('proportion', 'relative'), ('of', 'proportion'), ('the', 'of'), ('two', 'the'), ('discrimination', 'two'), ('experience', 'discrimination'), ('measure', 'experience'), ('across', 'measure'), ('each', 'across'), ('racial', 'each'), ('category', 'racial'), ('.', 'category')]
#
#  Testing Example sent_id : GUM_academic_discrimination-48, UAS Score: 0.25
# sentence: ['finally', ',', 'we', 'assess', 'the', 'distribution', 'of', 'report', 'reason', 'for', 'discrimination', 'across', 'the', 'racial', 'category', '.'], arc_set: [('finally', 'root'), (',', 'finally'), ('we', ','), ('assess', 'we'), ('the', 'assess'), ('distribution', 'the'), ('of', 'distribution'), ('report', 'of'), ('reason', 'report'), ('for', 'reason'), ('discrimination', 'for'), ('across', 'discrimination'), ('the', 'across'), ('racial', 'the'), ('category', 'racial'), ('.', 'category')]
#
#  Testing Example sent_id : GUM_academic_discrimination-49, UAS Score: 0.225
# sentence: ['in', 'order', 'to', 'examine', 'potential', 'bivariate', 'association', ',', 'the', 'adjust', 'F', 'statistic', '(', 'design', '-', 'base', 'F', ')', 'be', 'employ', 'as', 'it', 'correct', 'for', 'a', 'complex', 'sample', 'design', 'such', 'as', 'that', 'use', 'in', 'the', 'Add', 'Health', '.', '[', '21', ']'], arc_set: [('in', 'root'), ('order', 'in'), ('to', 'order'), ('examine', 'to'), ('potential', 'examine'), ('bivariate', 'potential'), ('association', 'bivariate'), (',', 'association'), ('the', ','), ('adjust', 'the'), ('F', 'adjust'), ('statistic', 'F'), ('(', 'statistic'), ('design', '('), ('-', 'design'), ('base', '-'), ('F', 'base'), (')', 'F'), ('be', ')'), ('employ', 'be'), ('as', 'employ'), ('it', 'as'), ('correct', 'it'), ('for', 'correct'), ('a', 'for'), ('complex', 'a'), ('sample', 'complex'), ('design', 'sample'), ('such', 'design'), ('as', 'such'), ('that', 'as'), ('use', 'that'), ('in', 'use'), ('the', 'in'), ('Add', 'the'), ('Health', 'Add'), ('.', 'Health'), ('[', '.'), ('21', '['), (']', '21')]
#
#  Testing Example sent_id : GUM_academic_discrimination-5, UAS Score: 0.35714285714285715
# sentence: ['sociologist', 'have', 'explore', 'the', 'adverse', 'consequence', 'of', 'discrimination', '[', '3', '-', '5', ']', ';'], arc_set: [('sociologist', 'root'), ('have', 'sociologist'), ('explore', 'have'), ('the', 'explore'), ('adverse', 'the'), ('consequence', 'adverse'), ('of', 'consequence'), ('discrimination', 'of'), ('[', 'discrimination'), ('3', '['), ('-', '3'), ('5', '-'), (']', '5'), (';', ']')]
#
#  Testing Example sent_id : GUM_academic_discrimination-50, UAS Score: 0.3387096774193548
# sentence: ['more', 'specifically', ',', 'when', 'analyze', 'weight', 'sample', 'datum', 'employ', 'the', 'svy', 'suite', 'of', 'command', 'in', 'Stata', 'the', 'conventional', 'Pearson', 'χ2', 'statistic', 'test', 'of', 'independence', 'be', 'convert', 'into', "''", 'a', 'F', 'statistic', 'with', 'noninteger', 'degree', 'of', 'freedom', 'by', 'use', 'a', 'second', '-', 'order', 'Rao', 'and', 'Scott', '(', '1981', '[', '22', ']', ',', '1984', '[', '23', ']', ')', 'correction', "''", '.', '[', '24', ']'], arc_set: [('more', 'root'), ('specifically', 'more'), (',', 'specifically'), ('when', ','), ('analyze', 'when'), ('weight', 'analyze'), ('sample', 'weight'), ('datum', 'sample'), ('employ', 'datum'), ('the', 'employ'), ('svy', 'the'), ('suite', 'svy'), ('of', 'suite'), ('command', 'of'), ('in', 'command'), ('Stata', 'in'), ('the', 'Stata'), ('conventional', 'the'), ('Pearson', 'conventional'), ('χ2', 'Pearson'), ('statistic', 'χ2'), ('test', 'statistic'), ('of', 'test'), ('independence', 'of'), ('be', 'independence'), ('convert', 'be'), ('into', 'convert'), ("''", 'into'), ('a', "''"), ('F', 'a'), ('statistic', 'F'), ('with', 'statistic'), ('noninteger', 'with'), ('degree', 'noninteger'), ('of', 'degree'), ('freedom', 'of'), ('by', 'freedom'), ('use', 'by'), ('a', 'use'), ('second', 'a'), ('-', 'second'), ('order', '-'), ('Rao', 'order'), ('and', 'Rao'), ('Scott', 'and'), ('(', 'Scott'), ('1981', '('), ('[', '1981'), ('22', '['), (']', '22'), (',', ']'), ('1984', ','), ('[', '1984'), ('23', '['), (']', '23'), (')', ']'), ('correction', ')'), ("''", 'correction'), ('.', "''"), ('[', '.'), ('24', '['), (']', '24')]
#
#  Testing Example sent_id : GUM_academic_discrimination-51, UAS Score: 0.3333333333333333
# sentence: ['the', 'p', '-', 'value', 'associate', 'with', 'the', 'design', '-', 'base', 'F', 'be', 'thus', 'more', 'accurate', '(', 'than', 'the', 'associate', 'with', 'the', 'χ2', 'statistic', ')', 'give', 'the', 'adjustment', 'and', 'calculation', 'take', 'into', 'account', 'the', 'weight', 'nature', 'of', 'the', 'datum', '.'], arc_set: [('the', 'root'), ('p', 'the'), ('-', 'p'), ('value', '-'), ('associate', 'value'), ('with', 'associate'), ('the', 'with'), ('design', 'the'), ('-', 'design'), ('base', '-'), ('F', 'base'), ('be', 'F'), ('thus', 'be'), ('more', 'thus'), ('accurate', 'more'), ('(', 'accurate'), ('than', '('), ('the', 'than'), ('associate', 'the'), ('with', 'associate'), ('the', 'with'), ('χ2', 'the'), ('statistic', 'χ2'), (')', 'statistic'), ('give', ')'), ('the', 'give'), ('adjustment', 'the'), ('and', 'adjustment'), ('calculation', 'and'), ('take', 'calculation'), ('into', 'take'), ('account', 'into'), ('the', 'account'), ('weight', 'the'), ('nature', 'weight'), ('of', 'nature'), ('the', 'of'), ('datum', 'the'), ('.', 'datum')]
#
#  Testing Example sent_id : GUM_academic_discrimination-52, UAS Score: 0.3181818181818182
# sentence: ['this', 'final', 'step', 'also', 'include', 'a', 'examination', 'of', 'the', 'relative', 'distribution', 'of', 'racial', 'category', 'across', 'the', 'various', 'report', 'reason', 'for', 'discrimination', '.'], arc_set: [('this', 'root'), ('final', 'this'), ('step', 'final'), ('also', 'step'), ('include', 'also'), ('a', 'include'), ('examination', 'a'), ('of', 'examination'), ('the', 'of'), ('relative', 'the'), ('distribution', 'relative'), ('of', 'distribution'), ('racial', 'of'), ('category', 'racial'), ('across', 'category'), ('the', 'across'), ('various', 'the'), ('report', 'various'), ('reason', 'report'), ('for', 'reason'), ('discrimination', 'for'), ('.', 'discrimination')]
#
#  Testing Example sent_id : GUM_academic_discrimination-53, UAS Score: 0.3055555555555556
# sentence: ['as', 'note', 'early', ',', 'all', 'analysis', 'be', 'weight', 'accord', 'to', 'the', 'survey', 'weight', 'provide', 'by', 'the', 'Add', 'Health', 'research', 'staff', 'and', 'standard', 'error', 'be', 'correct', 'for', 'the', 'clustering', 'and', 'stratification', 'that', 'define', 'the', 'sampling', 'strategy', '.'], arc_set: [('as', 'root'), ('note', 'as'), ('early', 'note'), (',', 'early'), ('all', ','), ('analysis', 'all'), ('be', 'analysis'), ('weight', 'be'), ('accord', 'weight'), ('to', 'accord'), ('the', 'to'), ('survey', 'the'), ('weight', 'survey'), ('provide', 'weight'), ('by', 'provide'), ('the', 'by'), ('Add', 'the'), ('Health', 'Add'), ('research', 'Health'), ('staff', 'research'), ('and', 'staff'), ('standard', 'and'), ('error', 'standard'), ('be', 'error'), ('correct', 'be'), ('for', 'correct'), ('the', 'for'), ('clustering', 'the'), ('and', 'clustering'), ('stratification', 'and'), ('that', 'stratification'), ('define', 'that'), ('the', 'define'), ('sampling', 'the'), ('strategy', 'sampling'), ('.', 'strategy')]
#
#  Testing Example sent_id : GUM_academic_discrimination-54, UAS Score: 0.25
# sentence: ['thus', ',', 'all', 'estimate', 'report', 'here', 'can', 'be', 'consider', 'nationally', 'representative', 'of', 'the', 'Unite', 'State', '.'], arc_set: [('thus', 'root'), (',', 'thus'), ('all', ','), ('estimate', 'all'), ('report', 'estimate'), ('here', 'report'), ('can', 'here'), ('be', 'can'), ('consider', 'be'), ('nationally', 'consider'), ('representative', 'nationally'), ('of', 'representative'), ('the', 'of'), ('Unite', 'the'), ('State', 'Unite'), ('.', 'State')]
#
#  Testing Example sent_id : GUM_academic_discrimination-6, UAS Score: 0.3125
# sentence: ['psychologist', 'have', 'examine', 'the', 'mental', 'process', 'that', 'underpin', 'conscious', 'and', 'unconscious', 'bias', '[', '6', ']', ';'], arc_set: [('psychologist', 'root'), ('have', 'psychologist'), ('examine', 'have'), ('the', 'examine'), ('mental', 'the'), ('process', 'mental'), ('that', 'process'), ('underpin', 'that'), ('conscious', 'underpin'), ('and', 'conscious'), ('unconscious', 'and'), ('bias', 'unconscious'), ('[', 'bias'), ('6', '['), (']', '6'), (';', ']')]
#
#  Testing Example sent_id : GUM_academic_discrimination-7, UAS Score: 0.35714285714285715
# sentence: ['neuroscientist', 'have', 'examine', 'the', 'neurobiological', 'underpinning', 'of', 'discrimination', '[', '7', '-', '9', ']', ';'], arc_set: [('neuroscientist', 'root'), ('have', 'neuroscientist'), ('examine', 'have'), ('the', 'examine'), ('neurobiological', 'the'), ('underpinning', 'neurobiological'), ('of', 'underpinning'), ('discrimination', 'of'), ('[', 'discrimination'), ('7', '['), ('-', '7'), ('9', '-'), (']', '9'), (';', ']')]
#
#  Testing Example sent_id : GUM_academic_discrimination-8, UAS Score: 0.2857142857142857
# sentence: ['and', 'evolutionary', 'theorist', 'have', 'explore', 'the', 'various', 'way', 'that', 'in', '-', 'group', '/', 'out', '-', 'group', 'bias', 'emerge', 'across', 'the', 'history', 'of', 'our', 'species', '.', '[', '10', ']'], arc_set: [('and', 'root'), ('evolutionary', 'and'), ('theorist', 'evolutionary'), ('have', 'theorist'), ('explore', 'have'), ('the', 'explore'), ('various', 'the'), ('way', 'various'), ('that', 'way'), ('in', 'that'), ('-', 'in'), ('group', '-'), ('/', 'group'), ('out', '/'), ('-', 'out'), ('group', '-'), ('bias', 'group'), ('emerge', 'bias'), ('across', 'emerge'), ('the', 'across'), ('history', 'the'), ('of', 'history'), ('our', 'of'), ('species', 'our'), ('.', 'species'), ('[', '.'), ('10', '['), (']', '10')]
#
#  Testing Example sent_id : GUM_academic_discrimination-9, UAS Score: 0.375
# sentence: ['in', 'many', 'respect', ',', 'researcher', 'already', 'possess', 'a', 'wealth', 'of', 'knowledge', 'concern', 'the', 'origin', 'and', 'consequence', 'of', 'discrimination', 'and', 'bias', '.', '[', '11', ']'], arc_set: [('in', 'root'), ('many', 'in'), ('respect', 'many'), (',', 'respect'), ('researcher', ','), ('already', 'researcher'), ('possess', 'already'), ('a', 'possess'), ('wealth', 'a'), ('of', 'wealth'), ('knowledge', 'of'), ('concern', 'knowledge'), ('the', 'concern'), ('origin', 'the'), ('and', 'origin'), ('consequence', 'and'), ('of', 'consequence'), ('discrimination', 'of'), ('and', 'discrimination'), ('bias', 'and'), ('.', 'bias'), ('[', '.'), ('11', '['), (']', '11')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-1, UAS Score: 0.3333333333333333
# sentence: ['2.', 'Gujjolaay', 'Eegimaa', ',', 'its', 'speaker', 'and', 'their', 'neighbour'], arc_set: [('2.', 'root'), ('Gujjolaay', '2.'), ('Eegimaa', 'Gujjolaay'), (',', 'Eegimaa'), ('its', ','), ('speaker', 'its'), ('and', 'speaker'), ('their', 'and'), ('neighbour', 'their')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-10, UAS Score: 0.3611111111111111
# sentence: ['Eegimaa', 'be', 'mainly', 'speak', 'in', 'Mof-Ávvi', ',', 'a', 'former', 'kingdom', 'of', '10', 'village', 'locate', 'to', 'the', 'west', 'of', 'Ziguinchor', ',', 'the', 'capital', 'city', 'of', 'the', 'former', 'administrative', 'region', 'of', 'Casamance', 'in', 'the', 'south', 'of', 'Senegal', '.'], arc_set: [('Eegimaa', 'root'), ('be', 'Eegimaa'), ('mainly', 'be'), ('speak', 'mainly'), ('in', 'speak'), ('Mof-Ávvi', 'in'), (',', 'Mof-Ávvi'), ('a', ','), ('former', 'a'), ('kingdom', 'former'), ('of', 'kingdom'), ('10', 'of'), ('village', '10'), ('locate', 'village'), ('to', 'locate'), ('the', 'to'), ('west', 'the'), ('of', 'west'), ('Ziguinchor', 'of'), (',', 'Ziguinchor'), ('the', ','), ('capital', 'the'), ('city', 'capital'), ('of', 'city'), ('the', 'of'), ('former', 'the'), ('administrative', 'former'), ('region', 'administrative'), ('of', 'region'), ('Casamance', 'of'), ('in', 'Casamance'), ('the', 'in'), ('south', 'the'), ('of', 'south'), ('Senegal', 'of'), ('.', 'Senegal')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-11, UAS Score: 0.30434782608695654
# sentence: ['Mof-Ávvi', 'be', 'a', 'peninsula', 'border', 'by', 'the', 'Casamance', 'River', 'to', 'the', 'north', ',', 'which', 'separate', 'it', 'from', 'the', 'Jóola', 'Búluf', 'and', 'Jóola', 'Fogny', 'area', ',', 'and', 'to', 'the', 'east', 'by', 'the', 'village', 'Brin', 'and', 'Djibonker', ',', 'where', 'the', 'speaker', 'of', 'Kujireray', 'and', 'Baïnounk', 'Gubëeher', 'live', '.'], arc_set: [('Mof-Ávvi', 'root'), ('be', 'Mof-Ávvi'), ('a', 'be'), ('peninsula', 'a'), ('border', 'peninsula'), ('by', 'border'), ('the', 'by'), ('Casamance', 'the'), ('River', 'Casamance'), ('to', 'River'), ('the', 'to'), ('north', 'the'), (',', 'north'), ('which', ','), ('separate', 'which'), ('it', 'separate'), ('from', 'it'), ('the', 'from'), ('Jóola', 'the'), ('Búluf', 'Jóola'), ('and', 'Búluf'), ('Jóola', 'and'), ('Fogny', 'Jóola'), ('area', 'Fogny'), (',', 'area'), ('and', ','), ('to', 'and'), ('the', 'to'), ('east', 'the'), ('by', 'east'), ('the', 'by'), ('village', 'the'), ('Brin', 'village'), ('and', 'Brin'), ('Djibonker', 'and'), (',', 'Djibonker'), ('where', ','), ('the', 'where'), ('speaker', 'the'), ('of', 'speaker'), ('Kujireray', 'of'), ('and', 'Kujireray'), ('Baïnounk', 'and'), ('Gubëeher', 'Baïnounk'), ('live', 'Gubëeher'), ('.', 'live')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-12, UAS Score: 0.3157894736842105
# sentence: ['in', 'the', 'south', ',', 'the', 'river', 'know', 'as', 'Kamobeul', 'Bolon', 'separate', 'Mof-Ávvi', 'from', 'the', 'Bayot', 'speak', 'area', ',', 'while', 'the', 'west', 'side', 'of', 'Mof-Ávvi', 'coincide', 'with', 'the', 'homeland', 'of', 'the', 'Jóola', 'Kaasa', 'Húluf', 'and', 'Jóola', 'Kaasa', 'Ésuulaaluʔ', '.'], arc_set: [('in', 'root'), ('the', 'in'), ('south', 'the'), (',', 'south'), ('the', ','), ('river', 'the'), ('know', 'river'), ('as', 'know'), ('Kamobeul', 'as'), ('Bolon', 'Kamobeul'), ('separate', 'Bolon'), ('Mof-Ávvi', 'separate'), ('from', 'Mof-Ávvi'), ('the', 'from'), ('Bayot', 'the'), ('speak', 'Bayot'), ('area', 'speak'), (',', 'area'), ('while', ','), ('the', 'while'), ('west', 'the'), ('side', 'west'), ('of', 'side'), ('Mof-Ávvi', 'of'), ('coincide', 'Mof-Ávvi'), ('with', 'coincide'), ('the', 'with'), ('homeland', 'the'), ('of', 'homeland'), ('the', 'of'), ('Jóola', 'the'), ('Kaasa', 'Jóola'), ('Húluf', 'Kaasa'), ('and', 'Húluf'), ('Jóola', 'and'), ('Kaasa', 'Jóola'), ('Ésuulaaluʔ', 'Kaasa'), ('.', 'Ésuulaaluʔ')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-13, UAS Score: 0.3225806451612903
# sentence: ['the', 'map', 'in', 'Figure', '2', 'below', ',', 'adapt', 'from', 'Palmeri', 'and', 'Gazio', '(', '1995', ')', ',', 'show', 'a', 'very', 'approximate', 'location', 'of', 'Mof-Ávvi', 'in', 'relation', 'to', 'other', 'neighbour', 'speech', 'community', '.'], arc_set: [('the', 'root'), ('map', 'the'), ('in', 'map'), ('Figure', 'in'), ('2', 'Figure'), ('below', '2'), (',', 'below'), ('adapt', ','), ('from', 'adapt'), ('Palmeri', 'from'), ('and', 'Palmeri'), ('Gazio', 'and'), ('(', 'Gazio'), ('1995', '('), (')', '1995'), (',', ')'), ('show', ','), ('a', 'show'), ('very', 'a'), ('approximate', 'very'), ('location', 'approximate'), ('of', 'location'), ('Mof-Ávvi', 'of'), ('in', 'Mof-Ávvi'), ('relation', 'in'), ('to', 'relation'), ('other', 'to'), ('neighbour', 'other'), ('speech', 'neighbour'), ('community', 'speech'), ('.', 'community')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-14, UAS Score: 0.3684210526315789
# sentence: ['some', 'of', 'this', 'community', 'will', 'be', 'refer', 'to', 'in', 'our', 'discussion', 'of', 'death', 'prevention', 'name', 'in', '§', '6', '.'], arc_set: [('some', 'root'), ('of', 'some'), ('this', 'of'), ('community', 'this'), ('will', 'community'), ('be', 'will'), ('refer', 'be'), ('to', 'refer'), ('in', 'to'), ('our', 'in'), ('discussion', 'our'), ('of', 'discussion'), ('death', 'of'), ('prevention', 'death'), ('name', 'prevention'), ('in', 'name'), ('§', 'in'), ('6', '§'), ('.', '6')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-15, UAS Score: 0.4117647058823529
# sentence: ['the', 'Eegimaa', 'speak', 'in', 'Mof-Ávvi', 'be', 'know', 'by', 'several', 'name', 'give', 'by', 'speaker', 'of', 'neighbour', 'language', '.'], arc_set: [('the', 'root'), ('Eegimaa', 'the'), ('speak', 'Eegimaa'), ('in', 'speak'), ('Mof-Ávvi', 'in'), ('be', 'Mof-Ávvi'), ('know', 'be'), ('by', 'know'), ('several', 'by'), ('name', 'several'), ('give', 'name'), ('by', 'give'), ('speaker', 'by'), ('of', 'speaker'), ('neighbour', 'of'), ('language', 'neighbour'), ('.', 'language')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-16, UAS Score: 0.3333333333333333
# sentence: ['for', 'example', ',', 'the', 'name', 'Kusiilay', '1', "'", 'the', 'language', 'of', 'Essil', "'", ',', 'be', 'the', 'name', 'give', 'by', 'speaker', 'of', 'Kujireray', 'to', 'the', 'Eegimaa', 'language', ',', 'because', 'Essil', ',', 'of', 'which', 'Bajjat', 'be', 'a', 'district', ',', 'be', 'the', 'village', 'which', 'have', 'a', 'border', 'with', 'their', 'village', '.'], arc_set: [('for', 'root'), ('example', 'for'), (',', 'example'), ('the', ','), ('name', 'the'), ('Kusiilay', 'name'), ('1', 'Kusiilay'), ("'", '1'), ('the', "'"), ('language', 'the'), ('of', 'language'), ('Essil', 'of'), ("'", 'Essil'), (',', "'"), ('be', ','), ('the', 'be'), ('name', 'the'), ('give', 'name'), ('by', 'give'), ('speaker', 'by'), ('of', 'speaker'), ('Kujireray', 'of'), ('to', 'Kujireray'), ('the', 'to'), ('Eegimaa', 'the'), ('language', 'Eegimaa'), (',', 'language'), ('because', ','), ('Essil', 'because'), (',', 'Essil'), ('of', ','), ('which', 'of'), ('Bajjat', 'which'), ('be', 'Bajjat'), ('a', 'be'), ('district', 'a'), (',', 'district'), ('be', ','), ('the', 'be'), ('village', 'the'), ('which', 'village'), ('have', 'which'), ('a', 'have'), ('border', 'a'), ('with', 'border'), ('their', 'with'), ('village', 'their'), ('.', 'village')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-17, UAS Score: 0.25
# sentence: ['Endungo', 'be', 'the', 'name', 'give', 'by', 'Bayot', 'speaker', ',', 'but', 'its', 'meaning', 'be', 'not', 'know', '.'], arc_set: [('Endungo', 'root'), ('be', 'Endungo'), ('the', 'be'), ('name', 'the'), ('give', 'name'), ('by', 'give'), ('Bayot', 'by'), ('speaker', 'Bayot'), (',', 'speaker'), ('but', ','), ('its', 'but'), ('meaning', 'its'), ('be', 'meaning'), ('not', 'be'), ('know', 'not'), ('.', 'know')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-18, UAS Score: 0.275
# sentence: ['Kúlaakiay', ',', "'", 'the', 'language', 'of', 'village', 'of', 'Seleki', '/', 'Sállagi', "'", ',', 'be', 'the', 'name', 'give', 'by', 'Jóola', 'Kaasa', 'speaker', 'who', 'be', 'more', 'familiar', 'with', 'the', 'village', 'of', 'Seleki', '/', 'Sállagi', "'", 'than', 'all', 'other', 'village', 'of', 'Mof-Ávvi', '.'], arc_set: [('Kúlaakiay', 'root'), (',', 'Kúlaakiay'), ("'", ','), ('the', "'"), ('language', 'the'), ('of', 'language'), ('village', 'of'), ('of', 'village'), ('Seleki', 'of'), ('/', 'Seleki'), ('Sállagi', '/'), ("'", 'Sállagi'), (',', "'"), ('be', ','), ('the', 'be'), ('name', 'the'), ('give', 'name'), ('by', 'give'), ('Jóola', 'by'), ('Kaasa', 'Jóola'), ('speaker', 'Kaasa'), ('who', 'speaker'), ('be', 'who'), ('more', 'be'), ('familiar', 'more'), ('with', 'familiar'), ('the', 'with'), ('village', 'the'), ('of', 'village'), ('Seleki', 'of'), ('/', 'Seleki'), ('Sállagi', '/'), ("'", 'Sállagi'), ('than', "'"), ('all', 'than'), ('other', 'all'), ('village', 'other'), ('of', 'village'), ('Mof-Ávvi', 'of'), ('.', 'Mof-Ávvi')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-19, UAS Score: 0.3050847457627119
# sentence: ['finally', ',', 'Banjal', '/', 'Bandial', "'", 'the', 'language', 'of', 'the', 'village', 'of', 'Banjal', "'", ',', 'the', 'most', 'popular', 'of', 'all', 'that', 'name', ',', 'be', 'the', 'name', 'give', 'by', 'the', 'Jóola', 'Búluf', 'and', 'Jóola', 'Fogny', 'speaker', 'to', 'Eegimaa', 'person', 'and', 'their', 'language', ',', 'because', 'person', 'from', 'the', 'village', 'of', 'Banjal', 'be', 'the', 'first', 'to', 'be', 'in', 'contact', 'with', 'they', '.'], arc_set: [('finally', 'root'), (',', 'finally'), ('Banjal', ','), ('/', 'Banjal'), ('Bandial', '/'), ("'", 'Bandial'), ('the', "'"), ('language', 'the'), ('of', 'language'), ('the', 'of'), ('village', 'the'), ('of', 'village'), ('Banjal', 'of'), ("'", 'Banjal'), (',', "'"), ('the', ','), ('most', 'the'), ('popular', 'most'), ('of', 'popular'), ('all', 'of'), ('that', 'all'), ('name', 'that'), (',', 'name'), ('be', ','), ('the', 'be'), ('name', 'the'), ('give', 'name'), ('by', 'give'), ('the', 'by'), ('Jóola', 'the'), ('Búluf', 'Jóola'), ('and', 'Búluf'), ('Jóola', 'and'), ('Fogny', 'Jóola'), ('speaker', 'Fogny'), ('to', 'speaker'), ('Eegimaa', 'to'), ('person', 'Eegimaa'), ('and', 'person'), ('their', 'and'), ('language', 'their'), (',', 'language'), ('because', ','), ('person', 'because'), ('from', 'person'), ('the', 'from'), ('village', 'the'), ('of', 'village'), ('Banjal', 'of'), ('be', 'Banjal'), ('the', 'be'), ('first', 'the'), ('to', 'first'), ('be', 'to'), ('in', 'be'), ('contact', 'in'), ('with', 'contact'), ('they', 'with'), ('.', 'they')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-2, UAS Score: 0.3333333333333333
# sentence: ['this', 'section', 'briefly', 'present', 'the', 'Gújjolaay', 'Eegimaa', '(', 'Eegimaa', 'for', 'short', ';', 'Ethnologue', 'code', ':', 'ISO', '639-3', ':', 'bqj', ')', ',', 'its', 'speaker', 'and', 'its', 'variety', '.'], arc_set: [('this', 'root'), ('section', 'this'), ('briefly', 'section'), ('present', 'briefly'), ('the', 'present'), ('Gújjolaay', 'the'), ('Eegimaa', 'Gújjolaay'), ('(', 'Eegimaa'), ('Eegimaa', '('), ('for', 'Eegimaa'), ('short', 'for'), (';', 'short'), ('Ethnologue', ';'), ('code', 'Ethnologue'), (':', 'code'), ('ISO', ':'), ('639-3', 'ISO'), (':', '639-3'), ('bqj', ':'), (')', 'bqj'), (',', ')'), ('its', ','), ('speaker', 'its'), ('and', 'speaker'), ('its', 'and'), ('variety', 'its'), ('.', 'variety')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-20, UAS Score: 0.0
# sentence: ['Figure', '1', '.'], arc_set: [('Figure', 'root'), ('1', 'Figure'), ('.', '1')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-21, UAS Score: 0.2222222222222222
# sentence: ['map', 'of', 'Senegal', '(', 'courtesy', 'of', 'Google', 'map', ')'], arc_set: [('map', 'root'), ('of', 'map'), ('Senegal', 'of'), ('(', 'Senegal'), ('courtesy', '('), ('of', 'courtesy'), ('Google', 'of'), ('map', 'Google'), (')', 'map')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-22, UAS Score: 0.0
# sentence: ['Figure', '2', '.'], arc_set: [('Figure', 'root'), ('2', 'Figure'), ('.', '2')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-23, UAS Score: 0.3333333333333333
# sentence: ['map', 'of', 'the', 'Eegimaa', 'speak', 'area'], arc_set: [('map', 'root'), ('of', 'map'), ('the', 'of'), ('Eegimaa', 'the'), ('speak', 'Eegimaa'), ('area', 'speak')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-24, UAS Score: 0.3333333333333333
# sentence: ['village', 'name', 'be', 'write', 'use', 'their', 'usual', 'spelling', '.'], arc_set: [('village', 'root'), ('name', 'village'), ('be', 'name'), ('write', 'be'), ('use', 'write'), ('their', 'use'), ('usual', 'their'), ('spelling', 'usual'), ('.', 'spelling')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-25, UAS Score: 0.3076923076923077
# ...
#
#  Testing Example sent_id : GUM_academic_eegimaa-32, UAS Score: 0.3
# sentence: ['nowadays', 'most', 'Eegimaa', 'speaker', 'from', 'Mof-Ávvi', 'live', 'outside', 'their', 'homeland', ',', 'generally', 'in', 'urban', 'area', 'like', 'Ziguinchor', 'and', 'Dakar', '.'], arc_set: [('nowadays', 'root'), ('most', 'nowadays'), ('Eegimaa', 'most'), ('speaker', 'Eegimaa'), ('from', 'speaker'), ('Mof-Ávvi', 'from'), ('live', 'Mof-Ávvi'), ('outside', 'live'), ('their', 'outside'), ('homeland', 'their'), (',', 'homeland'), ('generally', ','), ('in', 'generally'), ('urban', 'in'), ('area', 'urban'), ('like', 'area'), ('Ziguinchor', 'like'), ('and', 'Ziguinchor'), ('Dakar', 'and'), ('.', 'Dakar')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-33, UAS Score: 0.32432432432432434
# sentence: ['speaker', 'of', 'Eegimaa', 'use', 'the', 'term', 'Gújjolaay', '(', 'mean', 'Jóola', ')', 'to', 'refer', 'to', 'their', 'language', 'when', 'they', 'speak', 'to', 'each', 'other', ',', 'but', 'Eegimaa', 'to', 'distinguish', 'their', 'Jóola', 'variety', 'from', 'that', 'of', 'other', 'Jóola', 'people', '.'], arc_set: [('speaker', 'root'), ('of', 'speaker'), ('Eegimaa', 'of'), ('use', 'Eegimaa'), ('the', 'use'), ('term', 'the'), ('Gújjolaay', 'term'), ('(', 'Gújjolaay'), ('mean', '('), ('Jóola', 'mean'), (')', 'Jóola'), ('to', ')'), ('refer', 'to'), ('to', 'refer'), ('their', 'to'), ('language', 'their'), ('when', 'language'), ('they', 'when'), ('speak', 'they'), ('to', 'speak'), ('each', 'to'), ('other', 'each'), (',', 'other'), ('but', ','), ('Eegimaa', 'but'), ('to', 'Eegimaa'), ('distinguish', 'to'), ('their', 'distinguish'), ('Jóola', 'their'), ('variety', 'Jóola'), ('from', 'variety'), ('that', 'from'), ('of', 'that'), ('other', 'of'), ('Jóola', 'other'), ('people', 'Jóola'), ('.', 'people')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-34, UAS Score: 0.3157894736842105
# sentence: ['Eegimaa', 'be', 'a', 'endangered', 'language', 'whose', 'transmission', 'to', 'new', 'generation', 'have', 'be', 'decline', 'significantly', 'in', 'the', 'last', 'decade', '.'], arc_set: [('Eegimaa', 'root'), ('be', 'Eegimaa'), ('a', 'be'), ('endangered', 'a'), ('language', 'endangered'), ('whose', 'language'), ('transmission', 'whose'), ('to', 'transmission'), ('new', 'to'), ('generation', 'new'), ('have', 'generation'), ('be', 'have'), ('decline', 'be'), ('significantly', 'decline'), ('in', 'significantly'), ('the', 'in'), ('last', 'the'), ('decade', 'last'), ('.', 'decade')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-35, UAS Score: 0.23333333333333334
# sentence: ['it', 'be', 'important', 'to', 'understand', 'the', 'contact', 'situation', 'of', 'Eegimaa', ',', 'because', 'some', 'of', 'the', 'ritual', 'name', 'analyse', 'in', 'this', 'paper', 'come', 'from', 'other', 'language', 'or', 'from', 'neighbour', 'community', '.'], arc_set: [('it', 'root'), ('be', 'it'), ('important', 'be'), ('to', 'important'), ('understand', 'to'), ('the', 'understand'), ('contact', 'the'), ('situation', 'contact'), ('of', 'situation'), ('Eegimaa', 'of'), (',', 'Eegimaa'), ('because', ','), ('some', 'because'), ('of', 'some'), ('the', 'of'), ('ritual', 'the'), ('name', 'ritual'), ('analyse', 'name'), ('in', 'analyse'), ('this', 'in'), ('paper', 'this'), ('come', 'paper'), ('from', 'come'), ('other', 'from'), ('language', 'other'), ('or', 'language'), ('from', 'or'), ('neighbour', 'from'), ('community', 'neighbour'), ('.', 'community')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-36, UAS Score: 0.23076923076923078
# sentence: ['this', 'name', 'be', 'give', 'either', 'in', 'Eegimaa', 'or', 'in', 'a', 'different', 'language', '.'], arc_set: [('this', 'root'), ('name', 'this'), ('be', 'name'), ('give', 'be'), ('either', 'give'), ('in', 'either'), ('Eegimaa', 'in'), ('or', 'Eegimaa'), ('in', 'or'), ('a', 'in'), ('different', 'a'), ('language', 'different'), ('.', 'language')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-4, UAS Score: 0.2857142857142857
# sentence: ['this', 'be', 'important', ',', 'because', 'as', 'we', 'will', 'show', 'in', '§', '6', 'below', ',', 'some', 'of', 'the', 'Eegimaa', 'death', 'prevention', 'name', 'and', 'child', '-', 'bearing', 'name', 'be', 'give', 'to', 'Eegimaa', 'person', 'from', 'other', 'community', '.'], arc_set: [('this', 'root'), ('be', 'this'), ('important', 'be'), (',', 'important'), ('because', ','), ('as', 'because'), ('we', 'as'), ('will', 'we'), ('show', 'will'), ('in', 'show'), ('§', 'in'), ('6', '§'), ('below', '6'), (',', 'below'), ('some', ','), ('of', 'some'), ('the', 'of'), ('Eegimaa', 'the'), ('death', 'Eegimaa'), ('prevention', 'death'), ('name', 'prevention'), ('and', 'name'), ('child', 'and'), ('-', 'child'), ('bearing', '-'), ('name', 'bearing'), ('be', 'name'), ('give', 'be'), ('to', 'give'), ('Eegimaa', 'to'), ('person', 'Eegimaa'), ('from', 'person'), ('other', 'from'), ('community', 'other'), ('.', 'community')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-5, UAS Score: 0.34146341463414637
# sentence: ['Eegimaa', 'be', 'a', 'Jóola', 'language', 'speak', 'in', 'the', 'Basse', 'Casamance', 'area', 'of', 'Southern', 'Senegal', 'by', 'a', 'population', 'estimate', 'to', 'be', 'between', '7000', '(', 'Bassène', ',', '2007', ')', 'and', '11200', 'speaker', '(', 'Lewis', ',', 'Simons', ',', '&', 'Fennig', ',', '2014', ')', '.'], arc_set: [('Eegimaa', 'root'), ('be', 'Eegimaa'), ('a', 'be'), ('Jóola', 'a'), ('language', 'Jóola'), ('speak', 'language'), ('in', 'speak'), ('the', 'in'), ('Basse', 'the'), ('Casamance', 'Basse'), ('area', 'Casamance'), ('of', 'area'), ('Southern', 'of'), ('Senegal', 'Southern'), ('by', 'Senegal'), ('a', 'by'), ('population', 'a'), ('estimate', 'population'), ('to', 'estimate'), ('be', 'to'), ('between', 'be'), ('7000', 'between'), ('(', '7000'), ('Bassène', '('), (',', 'Bassène'), ('2007', ','), (')', '2007'), ('and', ')'), ('11200', 'and'), ('speaker', '11200'), ('(', 'speaker'), ('Lewis', '('), (',', 'Lewis'), ('Simons', ','), (',', 'Simons'), ('&', ','), ('Fennig', '&'), (',', 'Fennig'), ('2014', ','), (')', '2014'), ('.', ')')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-6, UAS Score: 0.4166666666666667
# sentence: ['Jóola', 'language', 'be', 'classify', 'as', 'member', 'of', 'Sapir', "'s", '(', '1971', ')', 'Bak', 'group', 'of', 'Atlantic', 'language', 'of', 'the', 'Niger', 'Congo', 'language', 'phylum', '.'], arc_set: [('Jóola', 'root'), ('language', 'Jóola'), ('be', 'language'), ('classify', 'be'), ('as', 'classify'), ('member', 'as'), ('of', 'member'), ('Sapir', 'of'), ("'s", 'Sapir'), ('(', "'s"), ('1971', '('), (')', '1971'), ('Bak', ')'), ('group', 'Bak'), ('of', 'group'), ('Atlantic', 'of'), ('language', 'Atlantic'), ('of', 'language'), ('the', 'of'), ('Niger', 'the'), ('Congo', 'Niger'), ('language', 'Congo'), ('phylum', 'language'), ('.', 'phylum')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-7, UAS Score: 0.30434782608695654
# sentence: ['speaker', 'of', 'this', 'language', 'be', 'find', 'in', 'the', 'Gambia', ',', 'in', 'the', 'former', 'Casamance', 'region', 'of', 'Southern', 'Senegal', 'and', 'in', 'Guinea', 'Bissau', '.'], arc_set: [('speaker', 'root'), ('of', 'speaker'), ('this', 'of'), ('language', 'this'), ('be', 'language'), ('find', 'be'), ('in', 'find'), ('the', 'in'), ('Gambia', 'the'), (',', 'Gambia'), ('in', ','), ('the', 'in'), ('former', 'the'), ('Casamance', 'former'), ('region', 'Casamance'), ('of', 'region'), ('Southern', 'of'), ('Senegal', 'Southern'), ('and', 'Senegal'), ('in', 'and'), ('Guinea', 'in'), ('Bissau', 'Guinea'), ('.', 'Bissau')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-8, UAS Score: 0.3125
# sentence: ['the', 'map', 'in', 'Figure', '1', ',', 'take', 'from', 'Ethnologue', ',', 'present', 'the', 'language', 'of', 'Senegal', '.'], arc_set: [('the', 'root'), ('map', 'the'), ('in', 'map'), ('Figure', 'in'), ('1', 'Figure'), (',', '1'), ('take', ','), ('from', 'take'), ('Ethnologue', 'from'), (',', 'Ethnologue'), ('present', ','), ('the', 'present'), ('language', 'the'), ('of', 'language'), ('Senegal', 'of'), ('.', 'Senegal')]
#
#  Testing Example sent_id : GUM_academic_eegimaa-9, UAS Score: 0.30434782608695654
# sentence: ['the', 'arrow', 'on', 'the', 'map', 'point', 'to', 'the', 'Eegimaa', 'speak', 'area', '(', 'Bandial', 'be', 'the', 'name', 'use', 'by', 'Ethnologue', 'for', 'Eegimaa', ')', '.'], arc_set: [('the', 'root'), ('arrow', 'the'), ('on', 'arrow'), ('the', 'on'), ('map', 'the'), ('point', 'map'), ('to', 'point'), ('the', 'to'), ('Eegimaa', 'the'), ('speak', 'Eegimaa'), ('area', 'speak'), ('(', 'area'), ('Bandial', '('), ('be', 'Bandial'), ('the', 'be'), ('name', 'the'), ('use', 'name'), ('by', 'use'), ('Ethnologue', 'by'), ('for', 'Ethnologue'), ('Eegimaa', 'for'), (')', 'Eegimaa'), ('.', ')')]
#
#  Testing Example sent_id : GUM_bio_dvorak-1, UAS Score: 0.0
# sentence: ['Antonín', 'Dvořák'], arc_set: [('Antonín', 'root'), ('Dvořák', 'Antonín')]
#
#  Testing Example sent_id : GUM_bio_dvorak-10, UAS Score: 0.3333333333333333
# sentence: ['in', '1874', 'he', 'make', 'a', 'submission', 'to', 'the', 'Austrian', 'State', 'Prize', 'for', 'Composition', ',', 'include', 'score', 'of', 'two', 'further', 'symphony', 'and', 'other', 'work', '.'], arc_set: [('in', 'root'), ('1874', 'in'), ('he', '1874'), ('make', 'he'), ('a', 'make'), ('submission', 'a'), ('to', 'submission'), ('the', 'to'), ('Austrian', 'the'), ('State', 'Austrian'), ('Prize', 'State'), ('for', 'Prize'), ('Composition', 'for'), (',', 'Composition'), ('include', ','), ('score', 'include'), ('of', 'score'), ('two', 'of'), ('further', 'two'), ('symphony', 'further'), ('and', 'symphony'), ('other', 'and'), ('work', 'other'), ('.', 'work')]
#
#  Testing Example sent_id : GUM_bio_dvorak-2, UAS Score: 0.28125
# sentence: ['Antonín', 'Leopold', 'Dvořák', '(', '/', 'd(ə)ˈvɔːrʒɑːk', ',', '-ʒæk', '/', 'd(ə)-VOR-zha(h)k', ';', 'Czech', ':', '[', 'ˈantoɲiːn', 'ˈlɛopolt', 'ˈdvor̝aːk', ']', ';', '8', 'September', '1841', '-', '1', 'May', '1904', ')', 'be', 'a', 'Czech', 'composer', '.'], arc_set: [('Antonín', 'root'), ('Leopold', 'Antonín'), ('Dvořák', 'Leopold'), ('(', 'Dvořák'), ('/', '('), ('d(ə)ˈvɔːrʒɑːk', '/'), (',', 'd(ə)ˈvɔːrʒɑːk'), ('-ʒæk', ','), ('/', '-ʒæk'), ('d(ə)-VOR-zha(h)k', '/'), (';', 'd(ə)-VOR-zha(h)k'), ('Czech', ';'), (':', 'Czech'), ('[', ':'), ('ˈantoɲiːn', '['), ('ˈlɛopolt', 'ˈantoɲiːn'), ('ˈdvor̝aːk', 'ˈlɛopolt'), (']', 'ˈdvor̝aːk'), (';', ']'), ('8', ';'), ('September', '8'), ('1841', 'September'), ('-', '1841'), ('1', '-'), ('May', '1'), ('1904', 'May'), (')', '1904'), ('be', ')'), ('a', 'be'), ('Czech', 'a'), ('composer', 'Czech'), ('.', 'composer')]
#
#  Testing Example sent_id : GUM_bio_dvorak-3, UAS Score: 0.2222222222222222
# sentence: ['after', 'Bedřich', 'Smetana', ',', 'he', 'be', 'the', 'next', 'Czech', 'Romantic', '-', 'era', 'composer', 'to', 'achieve', 'worldwide', 'recognition', '.'], arc_set: [('after', 'root'), ('Bedřich', 'after'), ('Smetana', 'Bedřich'), (',', 'Smetana'), ('he', ','), ('be', 'he'), ('the', 'be'), ('next', 'the'), ('Czech', 'next'), ('Romantic', 'Czech'), ('-', 'Romantic'), ('era', '-'), ('composer', 'era'), ('to', 'composer'), ('achieve', 'to'), ('worldwide', 'achieve'), ('recognition', 'worldwide'), ('.', 'recognition')]
#
#  Testing Example sent_id : GUM_bio_dvorak-4, UAS Score: 0.28
# sentence: ['follow', 'Smetana', "'s", 'nationalist', 'example', ',', 'Dvořák', 'frequently', 'employ', 'aspect', ',', 'specifically', 'rhythm', ',', 'of', 'the', 'folk', 'music', 'of', 'Moravia', 'and', 'his', 'native', 'Bohemia', '.'], arc_set: [('follow', 'root'), ('Smetana', 'follow'), ("'s", 'Smetana'), ('nationalist', "'s"), ('example', 'nationalist'), (',', 'example'), ('Dvořák', ','), ('frequently', 'Dvořák'), ('employ', 'frequently'), ('aspect', 'employ'), (',', 'aspect'), ('specifically', ','), ('rhythm', 'specifically'), (',', 'rhythm'), ('of', ','), ('the', 'of'), ('folk', 'the'), ('music', 'folk'), ('of', 'music'), ('Moravia', 'of'), ('and', 'Moravia'), ('his', 'and'), ('native', 'his'), ('Bohemia', 'native'), ('.', 'Bohemia')]
#
#  Testing Example sent_id : GUM_bio_dvorak-5, UAS Score: 0.3684210526315789
# sentence: ['Dvořák', "'s", 'own', 'style', 'have', 'be', 'describe', 'as', "''", 'the', 'full', 'recreation', 'of', 'a', 'national', 'idiom', 'with', 'that', 'of', 'the', 'symphonic', 'tradition', ',', 'absorb', 'folk', 'influence', 'and', 'find', 'effective', 'way', 'of', 'use', 'they', "''", '.', '[', '1', ']'], arc_set: [('Dvořák', 'root'), ("'s", 'Dvořák'), ('own', "'s"), ('style', 'own'), ('have', 'style'), ('be', 'have'), ('describe', 'be'), ('as', 'describe'), ("''", 'as'), ('the', "''"), ('full', 'the'), ('recreation', 'full'), ('of', 'recreation'), ('a', 'of'), ('national', 'a'), ('idiom', 'national'), ('with', 'idiom'), ('that', 'with'), ('of', 'that'), ('the', 'of'), ('symphonic', 'the'), ('tradition', 'symphonic'), (',', 'tradition'), ('absorb', ','), ('folk', 'absorb'), ('influence', 'folk'), ('and', 'influence'), ('find', 'and'), ('effective', 'find'), ('way', 'effective'), ('of', 'way'), ('use', 'of'), ('they', 'use'), ("''", 'they'), ('.', "''"), ('[', '.'), ('1', '['), (']', '1')]
#
#  Testing Example sent_id : GUM_bio_dvorak-6, UAS Score: 0.0
# sentence: ['Antonín', 'Dvořák'], arc_set: [('Antonín', 'root'), ('Dvořák', 'Antonín')]
#
#  Testing Example sent_id : GUM_bio_dvorak-7, UAS Score: 0.2631578947368421
# sentence: ['Dvořák', 'display', 'his', 'musical', 'gift', 'at', 'a', 'early', 'age', ',', 'be', 'a', 'apt', 'violin', 'student', 'from', 'age', 'six', '.'], arc_set: [('Dvořák', 'root'), ('display', 'Dvořák'), ('his', 'display'), ('musical', 'his'), ('gift', 'musical'), ('at', 'gift'), ('a', 'at'), ('early', 'a'), ('age', 'early'), (',', 'age'), ('be', ','), ('a', 'be'), ('apt', 'a'), ('violin', 'apt'), ('student', 'violin'), ('from', 'student'), ('age', 'from'), ('six', 'age'), ('.', 'six')]
#
#  Testing Example sent_id : GUM_bio_dvorak-8, UAS Score: 0.2962962962962963
# sentence: ['the', 'first', 'public', 'performance', 'of', 'his', 'work', 'be', 'in', 'Prague', 'in', '1872', 'and', ',', 'with', 'special', 'success', ',', 'in', '1873', ',', 'when', 'he', 'be', 'aged', '31', '.'], arc_set: [('the', 'root'), ('first', 'the'), ('public', 'first'), ('performance', 'public'), ('of', 'performance'), ('his', 'of'), ('work', 'his'), ('be', 'work'), ('in', 'be'), ('Prague', 'in'), ('in', 'Prague'), ('1872', 'in'), ('and', '1872'), (',', 'and'), ('with', ','), ('special', 'with'), ('success', 'special'), (',', 'success'), ('in', ','), ('1873', 'in'), (',', '1873'), ('when', ','), ('he', 'when'), ('be', 'he'), ('aged', 'be'), ('31', 'aged'), ('.', '31')]
#
#  Testing Example sent_id : GUM_bio_dvorak-9, UAS Score: 0.28205128205128205
# sentence: ['seek', 'recognition', 'beyond', 'the', 'Prague', 'area', ',', 'he', 'submit', 'a', 'score', 'of', 'his', 'First', 'Symphony', 'to', 'a', 'prize', 'competition', 'in', 'Germany', ',', 'but', 'do', 'not', 'win', ',', 'and', 'the', 'unreturned', 'manuscript', 'be', 'lose', 'until', 'rediscover', 'many', 'decade', 'late', '.'], arc_set: [('seek', 'root'), ('recognition', 'seek'), ('beyond', 'recognition'), ('the', 'beyond'), ('Prague', 'the'), ('area', 'Prague'), (',', 'area'), ('he', ','), ('submit', 'he'), ('a', 'submit'), ('score', 'a'), ('of', 'score'), ('his', 'of'), ('First', 'his'), ('Symphony', 'First'), ('to', 'Symphony'), ('a', 'to'), ('prize', 'a'), ('competition', 'prize'), ('in', 'competition'), ('Germany', 'in'), (',', 'Germany'), ('but', ','), ('do', 'but'), ('not', 'do'), ('win', 'not'), (',', 'win'), ('and', ','), ('the', 'and'), ('unreturned', 'the'), ('manuscript', 'unreturned'), ('be', 'manuscript'), ('lose', 'be'), ('until', 'lose'), ('rediscover', 'until'), ('many', 'rediscover'), ('decade', 'many'), ('late', 'decade'), ('.', 'late')]
# Average UAS Score over Test Data: 0.27649188475321057

# %%
df_test.head(10)
# Out:
#                          sent_id  \
# 0  GUM_academic_discrimination-1
# 1  GUM_academic_discrimination-1
# 2  GUM_academic_discrimination-1
# 3  GUM_academic_discrimination-1
# 4  GUM_academic_discrimination-1
# 5  GUM_academic_discrimination-1
# 6  GUM_academic_discrimination-1
# 7  GUM_academic_discrimination-1
# 8  GUM_academic_discrimination-1
# 9  GUM_academic_discrimination-1
#
#                                                 text            word  \
# 0  The prevalence of discrimination across racial...             The
# 1  The prevalence of discrimination across racial...      prevalence
# 2  The prevalence of discrimination across racial...              of
# 3  The prevalence of discrimination across racial...  discrimination
# 4  The prevalence of discrimination across racial...          across
# 5  The prevalence of discrimination across racial...          racial
# 6  The prevalence of discrimination across racial...          groups
# 7  The prevalence of discrimination across racial...              in
# 8  The prevalence of discrimination across racial...    contemporary
# 9  The prevalence of discrimination across racial...         America
#
#   normalized_word POS_tag head_word_index dependency_relation  \
# 0             the      DT               1                 det
# 1      prevalence      NN               2                root
# 2              of      IN               3                case
# 3  discrimination      NN               4                nmod
# 4          across      IN               5                case
# 5          racial      JJ               6                amod
# 6           group     NNS               7                nmod
# 7              in      IN               8                case
# 8    contemporary      JJ               9                amod
# 9         America     NNP              10                nmod
#
#    normalized_word_index       head_word                dep_graph_True
# 0                    1.0      prevalence             (prevalence, the)
# 1                    2.0            root            (root, prevalence)
# 2                    3.0  discrimination          (discrimination, of)
# 3                    4.0      prevalence  (prevalence, discrimination)
# 4                    5.0           group               (group, across)
# 5                    6.0           group               (group, racial)
# 6                    7.0      prevalence           (prevalence, group)
# 7                    8.0         America                 (America, in)
# 8                    9.0         America       (America, contemporary)
# 9                   10.0      prevalence         (prevalence, America)

# %%
df_test_output = pd.DataFrame(test_output)
df_test_output.head(10)
# Out:
#                          sent_id  token number            word  \
# 0  GUM_academic_discrimination-1             1             the
# 1  GUM_academic_discrimination-1             2      prevalence
# 2  GUM_academic_discrimination-1             3              of
# 3  GUM_academic_discrimination-1             4  discrimination
# 4  GUM_academic_discrimination-1             5          across
# 5  GUM_academic_discrimination-1             6          racial
# 6  GUM_academic_discrimination-1             7           group
# 7  GUM_academic_discrimination-1             8              in
# 8  GUM_academic_discrimination-1             9    contemporary
# 9  GUM_academic_discrimination-1            10         America
#
#   predicted_head_token
# 0           prevalence
# 1                   of
# 2       discrimination
# 3               across
# 4               racial
# 5                group
# 6                   in
# 7         contemporary
# 8              America
# 9                    :

# %%
df_test_output['normalized_word_index'] = df_test_output.groupby('sent_id').cumcount()+ 1

# %%
for index, row in df_test_output.iterrows():
    if row['predicted_head_token'] == 'root':
        df_test_output.at[index, 'predicted head token number'] = 0
    else:
        df_2 = df_test_output[(df_test_output['sent_id'] == row['sent_id']) & (df_test_output['word'] == row['predicted_head_token'])]
        if not df_2.empty:
            predicted_head_token_index = int(df_2['normalized_word_index'].iloc[0])
            df_test_output.at[index, 'predicted head token number'] = int(predicted_head_token_index)

# %%
df_test_output.head(25)
# Out:
#                            sent_id  token number            word  \
# 0    GUM_academic_discrimination-1             1             the
# 1    GUM_academic_discrimination-1             2      prevalence
# 2    GUM_academic_discrimination-1             3              of
# 3    GUM_academic_discrimination-1             4  discrimination
# 4    GUM_academic_discrimination-1             5          across
# 5    GUM_academic_discrimination-1             6          racial
# 6    GUM_academic_discrimination-1             7           group
# 7    GUM_academic_discrimination-1             8              in
# 8    GUM_academic_discrimination-1             9    contemporary
# 9    GUM_academic_discrimination-1            10         America
# 10   GUM_academic_discrimination-1            11               :
# 11  GUM_academic_discrimination-10             1            what
# 12  GUM_academic_discrimination-10             2            also
# 13  GUM_academic_discrimination-10             3          should
# 14  GUM_academic_discrimination-10             4             not
# 15  GUM_academic_discrimination-10             5              be
# 16  GUM_academic_discrimination-10             6            lose
# 17  GUM_academic_discrimination-10             7              in
# 18  GUM_academic_discrimination-10             8      discussion
# 19  GUM_academic_discrimination-10             9              of
# 20  GUM_academic_discrimination-10            10  discrimination
# 21  GUM_academic_discrimination-10            11              be
# 22  GUM_academic_discrimination-10            12             the
# 23  GUM_academic_discrimination-10            13            grow
# 24  GUM_academic_discrimination-10            14            push
#
#    predicted_head_token  normalized_word_index  predicted head token number
# 0            prevalence                      1                          2.0
# 1                    of                      2                          3.0
# 2        discrimination                      3                          4.0
# 3                across                      4                          5.0
# 4                racial                      5                          6.0
# 5                 group                      6                          7.0
# 6                    in                      7                          8.0
# 7          contemporary                      8                          9.0
# 8               America                      9                         10.0
# 9                     :                     10                         11.0
# 10                 None                     11                          NaN
# 11                 also                      1                          2.0
# 12               should                      2                          3.0
# 13                  not                      3                          4.0
# 14                   be                      4                          5.0
# 15                  the                      5                         12.0
# 16                   in                      6                          7.0
# 17           discussion                      7                          8.0
# 18                   of                      8                          9.0
# 19       discriminatory                      9                         25.0
# 20                   be                     10                          5.0
# 21                  the                     11                         12.0
# 22           occurrence                     12                         23.0
# 23                 push                     13                         14.0
# 24                   to                     14                         15.0

# %%
df_test_output['predicted head token number'].isna().sum()
# Out:
# 98

# %%
df_test_output.drop(columns=['normalized_word_index','predicted_head_token'], inplace = True)

# %% [markdown]
# Nan values in the column predicted_head_token_index shows that model was not able to find head word of corresponding word.

# %%
df_test_output = df_test_output[['sent_id', 'token number', 'word', 'predicted head token number']]
df_test_output.head()
# Out:
#                          sent_id  token number            word  \
# 0  GUM_academic_discrimination-1             1             the
# 1  GUM_academic_discrimination-1             2      prevalence
# 2  GUM_academic_discrimination-1             3              of
# 3  GUM_academic_discrimination-1             4  discrimination
# 4  GUM_academic_discrimination-1             5          across
#
#    predicted head token number
# 0                          2.0
# 1                          3.0
# 2                          4.0
# 3                          5.0
# 4                          6.0

# %%
tsv_file_path = 'dependency_predictions_on.tsv'

# Write the DataFrame to the TSV file
df_test_output.to_csv(tsv_file_path, sep='\t', index=False)
print("TSV file has been created successfully.")
# Out:
# TSV file has been created successfully.
